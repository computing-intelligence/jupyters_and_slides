# %% [markdown]
# ## The simplest Machine Leanring Model

# %%
import numpy as np

# %%
def f(x):
    return np.sin(x**2) ** 10

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
X = np.linspace(-100, 500, 500)

# %%
plt.plot(f(X))

# %%
sample = np.random.choice(X, size=50)

# %%
plt.plot(sample)

# %%
def knn(x):
    pass

# %% [markdown]
# ## KNN classification example

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Users/gaominquan/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /Users/gaominquan/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
dfx = pd.read_csv('datasets/xdata.csv')
dfy = pd.read_csv('datasets/ydata.csv')

# %%
X = dfx.values
Y = dfy.values

X = X[:,1:]
Y = Y[:,1:].reshape((-1,))

#print(X)

print(X.shape)
print(Y.shape)

#print(Y)
# Out:
# (399, 2)
# (399,)

# %%
plt.scatter(X[:,0],X[:,1],c=Y)
plt.show()

# %%
query_x = np.array([2,3])
plt.scatter(X[:,0],X[:,1],c=Y)
plt.scatter(query_x[0],query_x[1],color='red')
plt.show()

# %%
def dist(x1,x2):
    return np.sqrt(sum((x1-x2)**2))

# Test Time 
def knn(X,Y,queryPoint,k=5):
    
    vals = []
    m = X.shape[0]
    
    for i in range(m):
        d = dist(queryPoint,X[i])
        vals.append((d,Y[i]))
        
    
    vals = sorted(vals)
    # Nearest/First K points
    vals = vals[:k]
    
    vals = np.array(vals)
    
    #print(vals)
    
    new_vals = np.unique(vals[:,1],return_counts=True)
    #print(new_vals)
    
    index = new_vals[1].argmax()
    pred = new_vals[0][index]
    
    return pred

# %%
x = knn(X,Y,[0,0])
print(x)
# Out:
# 1.0

# %% [markdown]
# ## KNN is powerful and simple

# %% [markdown]
# # KNN has better explaination performance

# %% [markdown]
# # Lazy Leanring and Eager Leanring
