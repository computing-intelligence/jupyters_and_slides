# %%
from gensim.models.word2vec import LineSentence

# %%
# !ls
# Out:
# Lecture-01.ipynb
# Lecture-04-Dynamic-Programming.ipynb
# Lesson-02-LanguageModel-and-Machine-Learning.ipynb
# Lesson-03-Machine-Learning-Start-And-Heusric-Search.ipynb
# Mathematical - Foundation-Part-2.ipynb
# Mathmatical-Foundation-01.ipynb
# Picture1.png
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# assignments
# historys.txt
# lesson_03_titanic_mahchine_learning.py
# programming-ability-testing
# python-sci-computing

# %%
from gensim.models import Word2Vec

# %%
sentences = [["cat", "say", "meow"], ["dog", "say", "woof"]]
model = Word2Vec(sentences, min_count=1)

# %%
model.wv.vocab
# Out:
# {'cat': <gensim.models.keyedvectors.Vocab at 0x124b9e978>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x124b9e9e8>,
#  'meow': <gensim.models.keyedvectors.Vocab at 0x124b9eb38>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x124b9eba8>,
#  'woof': <gensim.models.keyedvectors.Vocab at 0x124b9ec18>}

# %%
model.most_similar('cat')
# Out:
# /Users/mqgao/anaconda3/envs/fastprint/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /Users/mqgao/anaconda3/envs/fastprint/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('meow', 0.21285688877105713),
#  ('woof', 0.09219974279403687),
#  ('dog', 0.06287731230258942),
#  ('say', -0.007907144725322723)]

# %%
model.wv['dog']
# Out:
# array([ 2.5794671e-03, -1.9936932e-03,  3.5095529e-03, -4.9303286e-03,
#         1.9047247e-03, -7.5721869e-04,  3.3417617e-03,  2.3645139e-03,
#        -9.7631355e-04,  2.9735011e-03,  2.3731249e-03, -1.5563420e-03,
#        -2.2508672e-03,  1.5577269e-03, -2.4221672e-03,  1.3880561e-03,
#         3.6401683e-03, -4.6348250e-03,  9.7287010e-04, -4.4322778e-03,
#        -3.0515885e-03, -3.8625393e-03,  3.5922446e-03,  2.6436355e-03,
#        -6.6917273e-05, -3.4233914e-03,  1.0001331e-03,  1.9670532e-03,
#        -4.2160861e-03, -2.7076502e-03,  2.4539311e-04,  3.7665839e-05,
#        -1.8875458e-03, -5.6261913e-04, -2.3102683e-03,  2.4158452e-03,
#        -1.6565557e-03, -4.5575690e-03, -2.3554548e-04, -1.9414768e-03,
#         3.5555854e-03,  4.6294071e-03,  1.8884481e-03, -4.2554098e-03,
#        -3.3694452e-03,  3.5314003e-03, -3.3302046e-03,  2.2710196e-03,
#        -2.5972438e-03,  3.0473652e-03, -1.6689721e-03,  3.9232462e-03,
#        -2.2696226e-03, -4.8952051e-03,  1.7844408e-03, -1.7685489e-03,
#         8.2847429e-04,  4.2296718e-03, -3.3543424e-03,  1.7066272e-03,
#         1.5303526e-03, -3.1699564e-03,  4.8367956e-04, -2.7484132e-03,
#        -2.7560936e-03, -2.1115888e-03,  2.1012048e-03,  1.5334166e-03,
#         3.2819537e-03,  4.3850746e-03,  4.0687742e-03,  1.2458622e-03,
#        -1.6269417e-03, -1.3944551e-03,  1.5153581e-03,  1.1060504e-03,
#        -3.8744172e-04,  7.9624628e-04,  5.8955170e-04, -4.4648629e-03,
#         3.5477835e-03,  3.4801704e-03, -3.5018446e-03, -2.4893342e-03,
#        -8.4955926e-04, -3.6001939e-03,  3.8928895e-03,  1.7207676e-03,
#         1.0639179e-03, -4.7545359e-03,  1.5445979e-03,  3.0536021e-03,
#        -2.0592580e-04,  2.6583900e-03,  1.1584706e-03,  2.4818224e-04,
#        -2.4813740e-03,  1.6689861e-04,  4.4449754e-03, -3.7832762e-04],
#       dtype=float32)

# %%
database = '/Users/mqgao/Workspace/Lecture/datasource/sqlResult_1558435.csv'

# %%
import pandas as pd

# %%
content = pd.read_csv(database, encoding='gb18030')

# %%
samples = content['content'][:100].tolist()

# %%
import jieba

# %%
def cut(string): return ' '.join(jieba.cut(string))

# %%
cut('这是一个测试')
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/lx/xy106sq15v1c9hbk_hg9wbdh0000gn/T/jieba.cache
# Loading model cost 0.935 seconds.
# Prefix dict has been built succesfully.
# '这是 一个 测试'

# %%
with open('mini_samples.txt', 'w') as f:
    for s in samples: 
        f.write(cut(s) + '\n')

# %%
sentences = LineSentence('mini_samples.txt')

# %%
model = Word2Vec(sentences, min_count=1)

# %%
model.wv['小米']
# Out:
# array([-0.00921484, -0.00287048, -0.04344053,  0.00717809,  0.00653802,
#         0.0479149 ,  0.01575128,  0.00805456,  0.01213742,  0.00714978,
#        -0.02140428, -0.05402831, -0.03454421, -0.01475686,  0.01221486,
#         0.01288561,  0.00675485, -0.01274678,  0.01232661, -0.0507661 ,
#         0.02310807,  0.04327806,  0.01508032,  0.02436008,  0.00958284,
#        -0.01941434, -0.01001354, -0.03212622, -0.03967742, -0.02848573,
#        -0.00078981, -0.04436494, -0.01237267,  0.00414971,  0.02253236,
#         0.00011204, -0.00720036,  0.02005151,  0.00403078, -0.01035645,
#         0.01037122, -0.00688439,  0.00387598,  0.00610097, -0.02078783,
#         0.04614076,  0.03037454,  0.00995713,  0.01964965,  0.02561241,
#        -0.02406882, -0.05268408,  0.01104352,  0.004234  ,  0.00940273,
#        -0.00954484,  0.03184672, -0.00963735, -0.03124459, -0.0038634 ,
#        -0.00741799, -0.02732982, -0.02418122, -0.01375151,  0.00822218,
#         0.00132964, -0.01748142,  0.01068539, -0.00371847,  0.01710978,
#         0.00603921, -0.0001745 ,  0.02087509,  0.06431138,  0.00299604,
#        -0.00726871,  0.02268715, -0.03598294,  0.01130471, -0.00666051,
#         0.00985309, -0.00023367, -0.0468699 ,  0.00589508, -0.01736601,
#        -0.01463194,  0.01574948, -0.00484399,  0.02994273,  0.00805919,
#         0.01205636,  0.00421771,  0.01601961, -0.00848926, -0.03089164,
#        -0.00921578, -0.00992675, -0.01534288,  0.01921713, -0.00512552],
#       dtype=float32)

# %%
model.most_similar('小米')
# Out:
# /Users/mqgao/anaconda3/envs/fastprint/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('预测', 0.9932690858840942),
#  ('英国', 0.9932618141174316),
#  ('标的', 0.9932584762573242),
#  ('升高', 0.9932108521461487),
#  ('益阳', 0.9930210113525391),
#  ('万达', 0.9930129051208496),
#  ('建设', 0.9930030107498169),
#  ('她', 0.9929219484329224),
#  ('能力', 0.9929120540618896),
#  ('款', 0.9928890466690063)]

# %%
model.wv.vocab
# Out:
# {'此外': <gensim.models.keyedvectors.Vocab at 0x12c1b44e0>,
#  '，': <gensim.models.keyedvectors.Vocab at 0x12c1b4358>,
#  '自': <gensim.models.keyedvectors.Vocab at 0x12c1b4390>,
#  '本周': <gensim.models.keyedvectors.Vocab at 0x12c1b45f8>,
#  '（': <gensim.models.keyedvectors.Vocab at 0x12c1b4630>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x12c1b4668>,
#  '月': <gensim.models.keyedvectors.Vocab at 0x12c1b46a0>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x12c1b46d8>,
#  '日': <gensim.models.keyedvectors.Vocab at 0x12c1b4710>,
#  '）': <gensim.models.keyedvectors.Vocab at 0x12c1b4748>,
#  '起': <gensim.models.keyedvectors.Vocab at 0x12c1b4780>,
#  '除': <gensim.models.keyedvectors.Vocab at 0x12c1b47b8>,
#  '小米': <gensim.models.keyedvectors.Vocab at 0x12c1b47f0>,
#  '手机': <gensim.models.keyedvectors.Vocab at 0x12c1b4828>,
#  '等': <gensim.models.keyedvectors.Vocab at 0x12c1b4860>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x12c1b4898>,
#  '款': <gensim.models.keyedvectors.Vocab at 0x12c1b48d0>,
#  '机型': <gensim.models.keyedvectors.Vocab at 0x12c1b4908>,
#  '外': <gensim.models.keyedvectors.Vocab at 0x12c1b4940>,
#  '其余': <gensim.models.keyedvectors.Vocab at 0x12c1b4978>,
#  '已': <gensim.models.keyedvectors.Vocab at 0x12c1b49b0>,
#  '暂停': <gensim.models.keyedvectors.Vocab at 0x12c1b49e8>,
#  '更新': <gensim.models.keyedvectors.Vocab at 0x12c1b4a20>,
#  '发布': <gensim.models.keyedvectors.Vocab at 0x12c1b4a58>,
#  '含': <gensim.models.keyedvectors.Vocab at 0x12c1b4a90>,
#  '开发': <gensim.models.keyedvectors.Vocab at 0x12c1b4ac8>,
#  '版': <gensim.models.keyedvectors.Vocab at 0x12c1b4b00>,
#  '/': <gensim.models.keyedvectors.Vocab at 0x12c1b4b38>,
#  '体验版': <gensim.models.keyedvectors.Vocab at 0x12c1b4b70>,
#  '内测': <gensim.models.keyedvectors.Vocab at 0x12c1b4ba8>,
#  '稳定版': <gensim.models.keyedvectors.Vocab at 0x12c1b4be0>,
#  '暂不受': <gensim.models.keyedvectors.Vocab at 0x12c1b4c18>,
#  '影响': <gensim.models.keyedvectors.Vocab at 0x12c1b4c50>,
#  '以': <gensim.models.keyedvectors.Vocab at 0x12c1b4c88>,
#  '确保': <gensim.models.keyedvectors.Vocab at 0x12c1b4cc0>,
#  '工程师': <gensim.models.keyedvectors.Vocab at 0x12c1b4cf8>,
#  '可以': <gensim.models.keyedvectors.Vocab at 0x12c1b4d30>,
#  '集中': <gensim.models.keyedvectors.Vocab at 0x12c1b4d68>,
#  '全部': <gensim.models.keyedvectors.Vocab at 0x12c1b4da0>,
#  '精力': <gensim.models.keyedvectors.Vocab at 0x12c1b4dd8>,
#  '进行': <gensim.models.keyedvectors.Vocab at 0x12c1b4e10>,
#  '系统优化': <gensim.models.keyedvectors.Vocab at 0x12c1b4e48>,
#  '工作': <gensim.models.keyedvectors.Vocab at 0x12c1b4e80>,
#  '。': <gensim.models.keyedvectors.Vocab at 0x12c1b4eb8>,
#  '有人': <gensim.models.keyedvectors.Vocab at 0x12c1b4ef0>,
#  '猜测': <gensim.models.keyedvectors.Vocab at 0x12c1b4f28>,
#  '这': <gensim.models.keyedvectors.Vocab at 0x12c1b4f60>,
#  '也': <gensim.models.keyedvectors.Vocab at 0x12c1b4f98>,
#  '是': <gensim.models.keyedvectors.Vocab at 0x12c1b4fd0>,
#  '将': <gensim.models.keyedvectors.Vocab at 0x12c1bb048>,
#  '主要': <gensim.models.keyedvectors.Vocab at 0x12c1bb080>,
#  '用到': <gensim.models.keyedvectors.Vocab at 0x12c1bb0b8>,
#  'MIUI': <gensim.models.keyedvectors.Vocab at 0x12c1bb0f0>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x12c1bb128>,
#  '的': <gensim.models.keyedvectors.Vocab at 0x12c1bb160>,
#  '研发': <gensim.models.keyedvectors.Vocab at 0x12c1bb198>,
#  '之中': <gensim.models.keyedvectors.Vocab at 0x12c1bb1d0>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x12c1bb208>,
#  '去年': <gensim.models.keyedvectors.Vocab at 0x12c1bb240>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x12c1bb278>,
#  '距今已有': <gensim.models.keyedvectors.Vocab at 0x12c1bb2b0>,
#  '一年': <gensim.models.keyedvectors.Vocab at 0x12c1bb2e8>,
#  '有余': <gensim.models.keyedvectors.Vocab at 0x12c1bb320>,
#  '时候': <gensim.models.keyedvectors.Vocab at 0x12c1bb358>,
#  '更新换代': <gensim.models.keyedvectors.Vocab at 0x12c1bb390>,
#  '了': <gensim.models.keyedvectors.Vocab at 0x12c1bb3c8>,
#  '当然': <gensim.models.keyedvectors.Vocab at 0x12c1bb400>,
#  '关于': <gensim.models.keyedvectors.Vocab at 0x12c1bb438>,
#  '确切': <gensim.models.keyedvectors.Vocab at 0x12c1bb470>,
#  '信息': <gensim.models.keyedvectors.Vocab at 0x12c1bb4a8>,
#  '我们': <gensim.models.keyedvectors.Vocab at 0x12c1bb4e0>,
#  '还是': <gensim.models.keyedvectors.Vocab at 0x12c1bb518>,
#  '等待': <gensim.models.keyedvectors.Vocab at 0x12c1bb550>,
#  '官方消息': <gensim.models.keyedvectors.Vocab at 0x12c1bb588>,
#  '骁龙': <gensim.models.keyedvectors.Vocab at 0x12c1bb5c0>,
#  '835': <gensim.models.keyedvectors.Vocab at 0x12c1bb5f8>,
#  '作为': <gensim.models.keyedvectors.Vocab at 0x12c1bb630>,
#  '唯一': <gensim.models.keyedvectors.Vocab at 0x12c1bb668>,
#  '通过': <gensim.models.keyedvectors.Vocab at 0x12c1bb6a0>,
#  'Windows': <gensim.models.keyedvectors.Vocab at 0x12c1bb6d8>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x12c1bb710>,
#  '桌面': <gensim.models.keyedvectors.Vocab at 0x12c1bb748>,
#  '平台': <gensim.models.keyedvectors.Vocab at 0x12c1bb780>,
#  '认证': <gensim.models.keyedvectors.Vocab at 0x12c1bb7b8>,
#  'ARM': <gensim.models.keyedvectors.Vocab at 0x12c1bb7f0>,
#  '处理器': <gensim.models.keyedvectors.Vocab at 0x12c1bb828>,
#  '高通': <gensim.models.keyedvectors.Vocab at 0x12c1bb860>,
#  '强调': <gensim.models.keyedvectors.Vocab at 0x12c1bb898>,
#  '不会': <gensim.models.keyedvectors.Vocab at 0x12c1bb8d0>,
#  '因为': <gensim.models.keyedvectors.Vocab at 0x12c1bb908>,
#  '只': <gensim.models.keyedvectors.Vocab at 0x12c1bb940>,
#  '考虑': <gensim.models.keyedvectors.Vocab at 0x12c1bb978>,
#  '性能': <gensim.models.keyedvectors.Vocab at 0x12c1bb9b0>,
#  '而': <gensim.models.keyedvectors.Vocab at 0x12c1bb9e8>,
#  '去': <gensim.models.keyedvectors.Vocab at 0x12c1bba20>,
#  '屏蔽掉': <gensim.models.keyedvectors.Vocab at 0x12c1bba58>,
#  '小': <gensim.models.keyedvectors.Vocab at 0x12c1bba90>,
#  '核心': <gensim.models.keyedvectors.Vocab at 0x12c1bbac8>,
#  '相反': <gensim.models.keyedvectors.Vocab at 0x12c1bbb00>,
#  '他们': <gensim.models.keyedvectors.Vocab at 0x12c1bbb38>,
#  '正': <gensim.models.keyedvectors.Vocab at 0x12c1bbb70>,
#  '联手': <gensim.models.keyedvectors.Vocab at 0x12c1bbba8>,
#  '微软': <gensim.models.keyedvectors.Vocab at 0x12c1bbbe0>,
#  '找到': <gensim.models.keyedvectors.Vocab at 0x12c1bbc18>,
#  '一种': <gensim.models.keyedvectors.Vocab at 0x12c1bbc50>,
#  '适合': <gensim.models.keyedvectors.Vocab at 0x12c1bbc88>,
#  '、': <gensim.models.keyedvectors.Vocab at 0x12c1bbcc0>,
#  '兼顾': <gensim.models.keyedvectors.Vocab at 0x12c1bbcf8>,
#  '和': <gensim.models.keyedvectors.Vocab at 0x12c1bbd30>,
#  '功耗': <gensim.models.keyedvectors.Vocab at 0x12c1bbd68>,
#  '完美': <gensim.models.keyedvectors.Vocab at 0x12c1bbda0>,
#  '方案': <gensim.models.keyedvectors.Vocab at 0x12c1bbdd8>,
#  '报道': <gensim.models.keyedvectors.Vocab at 0x12c1bbe10>,
#  '称': <gensim.models.keyedvectors.Vocab at 0x12c1bbe48>,
#  '已经': <gensim.models.keyedvectors.Vocab at 0x12c1bbe80>,
#  '拿到': <gensim.models.keyedvectors.Vocab at 0x12c1bbeb8>,
#  '一些': <gensim.models.keyedvectors.Vocab at 0x12c1bbef0>,
#  '新': <gensim.models.keyedvectors.Vocab at 0x12c1bbf28>,
#  '源码': <gensim.models.keyedvectors.Vocab at 0x12c1bbf60>,
#  '以便': <gensim.models.keyedvectors.Vocab at 0x12c1bbf98>,
#  '更好': <gensim.models.keyedvectors.Vocab at 0x12c1bbfd0>,
#  '地': <gensim.models.keyedvectors.Vocab at 0x12c1bc048>,
#  '理解': <gensim.models.keyedvectors.Vocab at 0x12c1bc080>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x12c1bc0b8>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x12c1bc0f0>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x12c1bc128>,
#  '架构': <gensim.models.keyedvectors.Vocab at 0x12c1bc160>,
#  '资料': <gensim.models.keyedvectors.Vocab at 0x12c1bc198>,
#  '显示': <gensim.models.keyedvectors.Vocab at 0x12c1bc1d0>,
#  '一款': <gensim.models.keyedvectors.Vocab at 0x12c1bc208>,
#  '集成': <gensim.models.keyedvectors.Vocab at 0x12c1bc240>,
#  'CPU': <gensim.models.keyedvectors.Vocab at 0x12c1bc278>,
#  'GPU': <gensim.models.keyedvectors.Vocab at 0x12c1bc2b0>,
#  '基带': <gensim.models.keyedvectors.Vocab at 0x12c1bc2e8>,
#  '蓝牙': <gensim.models.keyedvectors.Vocab at 0x12c1bc320>,
#  'Wi': <gensim.models.keyedvectors.Vocab at 0x12c1bc358>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x12c1bc390>,
#  'Fi': <gensim.models.keyedvectors.Vocab at 0x12c1bc3c8>,
#  'SoC': <gensim.models.keyedvectors.Vocab at 0x12c1bc400>,
#  '比': <gensim.models.keyedvectors.Vocab at 0x12c1bc438>,
#  '传统': <gensim.models.keyedvectors.Vocab at 0x12c1bc470>,
#  'Wintel': <gensim.models.keyedvectors.Vocab at 0x12c1bc4a8>,
#  '节省': <gensim.models.keyedvectors.Vocab at 0x12c1bc4e0>,
#  '至少': <gensim.models.keyedvectors.Vocab at 0x12c1bc518>,
#  '30%': <gensim.models.keyedvectors.Vocab at 0x12c1bc550>,
#  'PCB': <gensim.models.keyedvectors.Vocab at 0x12c1bc588>,
#  '空间': <gensim.models.keyedvectors.Vocab at 0x12c1bc5c0>,
#  '按计划': <gensim.models.keyedvectors.Vocab at 0x12c1bc5f8>,
#  '今年': <gensim.models.keyedvectors.Vocab at 0x12c1bc630>,
#  'Q4': <gensim.models.keyedvectors.Vocab at 0x12c1bc668>,
#  '华硕': <gensim.models.keyedvectors.Vocab at 0x12c1bc6a0>,
#  '惠普': <gensim.models.keyedvectors.Vocab at 0x12c1bc6d8>,
#  '联想': <gensim.models.keyedvectors.Vocab at 0x12c1bc710>,
#  '首发': <gensim.models.keyedvectors.Vocab at 0x12c1bc748>,
#  'Win10': <gensim.models.keyedvectors.Vocab at 0x12c1bc780>,
#  '电脑': <gensim.models.keyedvectors.Vocab at 0x12c1bc7b8>,
#  '预计': <gensim.models.keyedvectors.Vocab at 0x12c1bc7f0>,
#  '均': <gensim.models.keyedvectors.Vocab at 0x12c1bc828>,
#  '二合一': <gensim.models.keyedvectors.Vocab at 0x12c1bc860>,
#  '形态': <gensim.models.keyedvectors.Vocab at 0x12c1bc898>,
#  '产品': <gensim.models.keyedvectors.Vocab at 0x12c1bc8d0>,
#  '只是': <gensim.models.keyedvectors.Vocab at 0x12c1bc908>,
#  '个': <gensim.models.keyedvectors.Vocab at 0x12c1bc940>,
#  '开始': <gensim.models.keyedvectors.Vocab at 0x12c1bc978>,
#  '未来': <gensim.models.keyedvectors.Vocab at 0x12c1bc9b0>,
#  '也许': <gensim.models.keyedvectors.Vocab at 0x12c1bc9e8>,
#  '还': <gensim.models.keyedvectors.Vocab at 0x12c1bca20>,
#  '能': <gensim.models.keyedvectors.Vocab at 0x12c1bca58>,
#  '见到': <gensim.models.keyedvectors.Vocab at 0x12c1bca90>,
#  '三星': <gensim.models.keyedvectors.Vocab at 0x12c1bcac8>,
#  'Exynos': <gensim.models.keyedvectors.Vocab at 0x12c1bcb00>,
#  '联发科': <gensim.models.keyedvectors.Vocab at 0x12c1bcb38>,
#  '华为': <gensim.models.keyedvectors.Vocab at 0x12c1bcb70>,
#  '麒麟': <gensim.models.keyedvectors.Vocab at 0x12c1bcba8>,
#  '澎湃': <gensim.models.keyedvectors.Vocab at 0x12c1bcbe0>,
#  '进入': <gensim.models.keyedvectors.Vocab at 0x12c1bcc18>,
#  '此前': <gensim.models.keyedvectors.Vocab at 0x12c1bcc50>,
#  '一加': <gensim.models.keyedvectors.Vocab at 0x12c1bcc88>,
#  '3T': <gensim.models.keyedvectors.Vocab at 0x12c1bccc0>,
#  '搭载': <gensim.models.keyedvectors.Vocab at 0x12c1bccf8>,
#  '3400mAh': <gensim.models.keyedvectors.Vocab at 0x12c1bcd30>,
#  '电池': <gensim.models.keyedvectors.Vocab at 0x12c1bcd68>,
#  'DashCharge': <gensim.models.keyedvectors.Vocab at 0x12c1bcda0>,
#  '快充': <gensim.models.keyedvectors.Vocab at 0x12c1bcdd8>,
#  '规格': <gensim.models.keyedvectors.Vocab at 0x12c1bce10>,
#  '为': <gensim.models.keyedvectors.Vocab at 0x12c1bce48>,
#  '5V': <gensim.models.keyedvectors.Vocab at 0x12c1bce80>,
#  '4A': <gensim.models.keyedvectors.Vocab at 0x12c1bceb8>,
#  '至于': <gensim.models.keyedvectors.Vocab at 0x12c1bcef0>,
#  '缩水': <gensim.models.keyedvectors.Vocab at 0x12c1bcf28>,
#  '可能': <gensim.models.keyedvectors.Vocab at 0x12c1bcf60>,
#  '与': <gensim.models.keyedvectors.Vocab at 0x12c1bcf98>,
#  '刘作': <gensim.models.keyedvectors.Vocab at 0x12c1bcfd0>,
#  '虎': <gensim.models.keyedvectors.Vocab at 0x12c1bd048>,
#  '所说': <gensim.models.keyedvectors.Vocab at 0x12c1bd080>,
#  '要': <gensim.models.keyedvectors.Vocab at 0x12c1bd0b8>,
#  '做': <gensim.models.keyedvectors.Vocab at 0x12c1bd0f0>,
#  '市面': <gensim.models.keyedvectors.Vocab at 0x12c1bd128>,
#  '最': <gensim.models.keyedvectors.Vocab at 0x12c1bd160>,
#  '轻薄': <gensim.models.keyedvectors.Vocab at 0x12c1bd198>,
#  '大屏': <gensim.models.keyedvectors.Vocab at 0x12c1bd1d0>,
#  '旗舰': <gensim.models.keyedvectors.Vocab at 0x12c1bd208>,
#  '设定': <gensim.models.keyedvectors.Vocab at 0x12c1bd240>,
#  '有关': <gensim.models.keyedvectors.Vocab at 0x12c1bd278>,
#  '按照': <gensim.models.keyedvectors.Vocab at 0x12c1bd2b0>,
#  '目前': <gensim.models.keyedvectors.Vocab at 0x12c1bd2e8>,
#  '掌握': <gensim.models.keyedvectors.Vocab at 0x12c1bd320>,
#  '拥有': <gensim.models.keyedvectors.Vocab at 0x12c1bd358>,
#  '5.5': <gensim.models.keyedvectors.Vocab at 0x12c1bd390>,
#  '寸': <gensim.models.keyedvectors.Vocab at 0x12c1bd3c8>,
#  '1080P': <gensim.models.keyedvectors.Vocab at 0x12c1bd400>,
#  'AMOLED': <gensim.models.keyedvectors.Vocab at 0x12c1bd438>,
#  '显示屏': <gensim.models.keyedvectors.Vocab at 0x12c1bd470>,
#  '6G': <gensim.models.keyedvectors.Vocab at 0x12c1bd4a8>,
#  '8GB': <gensim.models.keyedvectors.Vocab at 0x12c1bd4e0>,
#  'RAM': <gensim.models.keyedvectors.Vocab at 0x12c1bd518>,
#  '64GB': <gensim.models.keyedvectors.Vocab at 0x12c1bd550>,
#  '128GB': <gensim.models.keyedvectors.Vocab at 0x12c1bd588>,
#  'ROM': <gensim.models.keyedvectors.Vocab at 0x12c1bd5c0>,
#  '双': <gensim.models.keyedvectors.Vocab at 0x12c1bd5f8>,
#  '1600': <gensim.models.keyedvectors.Vocab at 0x12c1bd630>,
#  '万': <gensim.models.keyedvectors.Vocab at 0x12c1bd668>,
#  '摄像头': <gensim.models.keyedvectors.Vocab at 0x12c1bd6a0>,
#  '备货': <gensim.models.keyedvectors.Vocab at 0x12c1bd6d8>,
#  '量': <gensim.models.keyedvectors.Vocab at 0x12c1bd710>,
#  '“': <gensim.models.keyedvectors.Vocab at 0x12c1bd748>,
#  '惊喜': <gensim.models.keyedvectors.Vocab at 0x12c1bd780>,
#  '”': <gensim.models.keyedvectors.Vocab at 0x12c1bd7b8>,
#  '根据': <gensim.models.keyedvectors.Vocab at 0x12c1bd7f0>,
#  '京东': <gensim.models.keyedvectors.Vocab at 0x12c1bd828>,
#  '泄露': <gensim.models.keyedvectors.Vocab at 0x12c1bd860>,
#  '售价': <gensim.models.keyedvectors.Vocab at 0x12c1bd898>,
#  'xx99': <gensim.models.keyedvectors.Vocab at 0x12c1bd8d0>,
#  '元': <gensim.models.keyedvectors.Vocab at 0x12c1bd908>,
#  '应该': <gensim.models.keyedvectors.Vocab at 0x12c1bd940>,
#  '在': <gensim.models.keyedvectors.Vocab at 0x12c1bd978>,
#  '2799': <gensim.models.keyedvectors.Vocab at 0x12c1bd9b0>,
#  '2899': <gensim.models.keyedvectors.Vocab at 0x12c1bd9e8>,
#  '2999': <gensim.models.keyedvectors.Vocab at 0x12c1bda20>,
#  '中': <gensim.models.keyedvectors.Vocab at 0x12c1bda58>,
#  '某个': <gensim.models.keyedvectors.Vocab at 0x12c1bda90>,
#  '这是': <gensim.models.keyedvectors.Vocab at 0x12c1bdac8>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x12c1bdb00>,
#  '葡萄牙': <gensim.models.keyedvectors.Vocab at 0x12c1bdb38>,
#  '中部': <gensim.models.keyedvectors.Vocab at 0x12c1bdb70>,
#  '大': <gensim.models.keyedvectors.Vocab at 0x12c1bdba8>,
#  '佩德罗': <gensim.models.keyedvectors.Vocab at 0x12c1bdbe0>,
#  '冈': <gensim.models.keyedvectors.Vocab at 0x12c1bdc18>,
#  '地区': <gensim.models.keyedvectors.Vocab at 0x12c1bdc50>,
#  '拍摄': <gensim.models.keyedvectors.Vocab at 0x12c1bdc88>,
#  '被': <gensim.models.keyedvectors.Vocab at 0x12c1bdcc0>,
#  '森林': <gensim.models.keyedvectors.Vocab at 0x12c1bdcf8>,
#  '大火': <gensim.models.keyedvectors.Vocab at 0x12c1bdd30>,
#  '烧毁': <gensim.models.keyedvectors.Vocab at 0x12c1bdd68>,
#  '汽车': <gensim.models.keyedvectors.Vocab at 0x12c1bdda0>,
#  '新华社': <gensim.models.keyedvectors.Vocab at 0x12c1bddd8>,
#  '记者': <gensim.models.keyedvectors.Vocab at 0x12c1bde10>,
#  '张立': <gensim.models.keyedvectors.Vocab at 0x12c1bde48>,
#  '云摄': <gensim.models.keyedvectors.Vocab at 0x12c1bde80>,
#  '原': <gensim.models.keyedvectors.Vocab at 0x12c1bdeb8>,
#  '标题': <gensim.models.keyedvectors.Vocab at 0x12c1bdef0>,
#  '：': <gensim.models.keyedvectors.Vocab at 0x12c1bdf28>,
#  '44': <gensim.models.keyedvectors.Vocab at 0x12c1bdf60>,
#  '岁': <gensim.models.keyedvectors.Vocab at 0x12c1bdf98>,
#  '女子': <gensim.models.keyedvectors.Vocab at 0x12c1bdfd0>,
#  '跑': <gensim.models.keyedvectors.Vocab at 0x12c1bf048>,
#  '深圳': <gensim.models.keyedvectors.Vocab at 0x12c1bf080>,
#  '约会': <gensim.models.keyedvectors.Vocab at 0x12c1bf0b8>,
#  '网友': <gensim.models.keyedvectors.Vocab at 0x12c1bf0f0>,
#  '拒': <gensim.models.keyedvectors.Vocab at 0x12c1bf128>,
#  '暴雨': <gensim.models.keyedvectors.Vocab at 0x12c1bf160>,
#  '裸身': <gensim.models.keyedvectors.Vocab at 0x12c1bf198>,
#  '奔走': <gensim.models.keyedvectors.Vocab at 0x12c1bf1d0>,
#  '…': <gensim.models.keyedvectors.Vocab at 0x12c1bf208>,
#  '@': <gensim.models.keyedvectors.Vocab at 0x12c1bf240>,
#  '交警': <gensim.models.keyedvectors.Vocab at 0x12c1bf278>,
#  '微博称': <gensim.models.keyedvectors.Vocab at 0x12c1bf2b0>,
#  '昨日': <gensim.models.keyedvectors.Vocab at 0x12c1bf2e8>,
#  '清晨': <gensim.models.keyedvectors.Vocab at 0x12c1bf320>,
#  '发现': <gensim.models.keyedvectors.Vocab at 0x12c1bf358>,
#  '有': <gensim.models.keyedvectors.Vocab at 0x12c1bf390>,
#  '一': <gensim.models.keyedvectors.Vocab at 0x12c1bf3c8>,
#  '赤裸': <gensim.models.keyedvectors.Vocab at 0x12c1bf400>,
#  '上身': <gensim.models.keyedvectors.Vocab at 0x12c1bf438>,
#  '行走': <gensim.models.keyedvectors.Vocab at 0x12c1bf470>,
#  '南坪': <gensim.models.keyedvectors.Vocab at 0x12c1bf4a8>,
#  '快速': <gensim.models.keyedvectors.Vocab at 0x12c1bf4e0>,
#  '上': <gensim.models.keyedvectors.Vocab at 0x12c1bf518>,
#  '期间': <gensim.models.keyedvectors.Vocab at 0x12c1bf550>,
#  '轻生': <gensim.models.keyedvectors.Vocab at 0x12c1bf588>,
#  '年头': <gensim.models.keyedvectors.Vocab at 0x12c1bf5c0>,
#  '一辅警': <gensim.models.keyedvectors.Vocab at 0x12c1bf5f8>,
#  '后': <gensim.models.keyedvectors.Vocab at 0x12c1bf630>,
#  '赶紧': <gensim.models.keyedvectors.Vocab at 0x12c1bf668>,
#  '其': <gensim.models.keyedvectors.Vocab at 0x12c1bf6a0>,
#  '披上': <gensim.models.keyedvectors.Vocab at 0x12c1bf6d8>,
#  '黄衣': <gensim.models.keyedvectors.Vocab at 0x12c1bf710>,
#  '并': <gensim.models.keyedvectors.Vocab at 0x12c1bf748>,
#  '一路': <gensim.models.keyedvectors.Vocab at 0x12c1bf780>,
#  '劝说': <gensim.models.keyedvectors.Vocab at 0x12c1bf7b8>,
#  '她': <gensim.models.keyedvectors.Vocab at 0x12c1bf7f0>,
#  '那么': <gensim.models.keyedvectors.Vocab at 0x12c1bf828>,
#  '事发': <gensim.models.keyedvectors.Vocab at 0x12c1bf860>,
#  '时': <gensim.models.keyedvectors.Vocab at 0x12c1bf898>,
#  '到底': <gensim.models.keyedvectors.Vocab at 0x12c1bf8d0>,
#  '都': <gensim.models.keyedvectors.Vocab at 0x12c1bf908>,
#  '发生': <gensim.models.keyedvectors.Vocab at 0x12c1bf940>,
#  '些': <gensim.models.keyedvectors.Vocab at 0x12c1bf978>,
#  '什么': <gensim.models.keyedvectors.Vocab at 0x12c1bf9b0>,
#  '呢': <gensim.models.keyedvectors.Vocab at 0x12c1bf9e8>,
#  '？': <gensim.models.keyedvectors.Vocab at 0x12c1bfa20>,
#  '南': <gensim.models.keyedvectors.Vocab at 0x12c1bfa58>,
#  '带': <gensim.models.keyedvectors.Vocab at 0x12c1bfa90>,
#  '您': <gensim.models.keyedvectors.Vocab at 0x12c1bfac8>,
#  '一起': <gensim.models.keyedvectors.Vocab at 0x12c1bfb00>,
#  '还原': <gensim.models.keyedvectors.Vocab at 0x12c1bfb38>,
#  '现场': <gensim.models.keyedvectors.Vocab at 0x12c1bfb70>,
#  '龙岗': <gensim.models.keyedvectors.Vocab at 0x12c1bfba8>,
#  '大队': <gensim.models.keyedvectors.Vocab at 0x12c1bfbe0>,
#  '坂田': <gensim.models.keyedvectors.Vocab at 0x12c1bfc18>,
#  '中队': <gensim.models.keyedvectors.Vocab at 0x12c1bfc50>,
#  '辅警': <gensim.models.keyedvectors.Vocab at 0x12c1bfc88>,
#  '刘青': <gensim.models.keyedvectors.Vocab at 0x12c1bfcc0>,
#  '女生': <gensim.models.keyedvectors.Vocab at 0x12c1bfcf8>,
#  '一位': <gensim.models.keyedvectors.Vocab at 0x12c1bfd30>,
#  '外表': <gensim.models.keyedvectors.Vocab at 0x12c1bfd68>,
#  '高大': <gensim.models.keyedvectors.Vocab at 0x12c1bfda0>,
#  '帅气': <gensim.models.keyedvectors.Vocab at 0x12c1bfdd8>,
#  '说话': <gensim.models.keyedvectors.Vocab at 0x12c1bfe10>,
#  '略带': <gensim.models.keyedvectors.Vocab at 0x12c1bfe48>,
#  '腼腆': <gensim.models.keyedvectors.Vocab at 0x12c1bfe80>,
#  '90': <gensim.models.keyedvectors.Vocab at 0x12c1bfeb8>,
#  '青年': <gensim.models.keyedvectors.Vocab at 0x12c1bfef0>,
#  '介绍': <gensim.models.keyedvectors.Vocab at 0x12c1bff28>,
#  '16': <gensim.models.keyedvectors.Vocab at 0x12c1bff60>,
#  '早上': <gensim.models.keyedvectors.Vocab at 0x12c1bff98>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x12c1bffd0>,
#  '36': <gensim.models.keyedvectors.Vocab at 0x12c1c1048>,
#  '分': <gensim.models.keyedvectors.Vocab at 0x12c1c1080>,
#  '他': <gensim.models.keyedvectors.Vocab at 0x12c1c10b8>,
#  '正在': <gensim.models.keyedvectors.Vocab at 0x12c1c10f0>,
#  '环城': <gensim.models.keyedvectors.Vocab at 0x12c1c1128>,
#  '南路': <gensim.models.keyedvectors.Vocab at 0x12c1c1160>,
#  '附近': <gensim.models.keyedvectors.Vocab at 0x12c1c1198>,
#  '值勤': <gensim.models.keyedvectors.Vocab at 0x12c1c11d0>,
#  '接到': <gensim.models.keyedvectors.Vocab at 0x12c1c1208>,
#  '机动车': <gensim.models.keyedvectors.Vocab at 0x12c1c1240>,
#  '危险': <gensim.models.keyedvectors.Vocab at 0x12c1c1278>,
#  '警情': <gensim.models.keyedvectors.Vocab at 0x12c1c12b0>,
#  '随后': <gensim.models.keyedvectors.Vocab at 0x12c1c12e8>,
#  '骑着': <gensim.models.keyedvectors.Vocab at 0x12c1c1320>,
#  '铁骑': <gensim.models.keyedvectors.Vocab at 0x12c1c1358>,
#  '沿路': <gensim.models.keyedvectors.Vocab at 0x12c1c1390>,
#  '寻找': <gensim.models.keyedvectors.Vocab at 0x12c1c13c8>,
#  '大概': <gensim.models.keyedvectors.Vocab at 0x12c1c1400>,
#  '花': <gensim.models.keyedvectors.Vocab at 0x12c1c1438>,
#  '十多分钟': <gensim.models.keyedvectors.Vocab at 0x12c1c1470>,
#  '大道': <gensim.models.keyedvectors.Vocab at 0x12c1c14a8>,
#  '出口': <gensim.models.keyedvectors.Vocab at 0x12c1c14e0>,
#  '往': <gensim.models.keyedvectors.Vocab at 0x12c1c1518>,
#  '方向': <gensim.models.keyedvectors.Vocab at 0x12c1c1550>,
#  '逆行': <gensim.models.keyedvectors.Vocab at 0x12c1c1588>,
#  '辅道': <gensim.models.keyedvectors.Vocab at 0x12c1c15c0>,
#  '该': <gensim.models.keyedvectors.Vocab at 0x12c1c15f8>,
#  '身上': <gensim.models.keyedvectors.Vocab at 0x12c1c1630>,
#  '一丝不挂': <gensim.models.keyedvectors.Vocab at 0x12c1c1668>,
#  '地逆': <gensim.models.keyedvectors.Vocab at 0x12c1c16a0>,
#  '车流': <gensim.models.keyedvectors.Vocab at 0x12c1c16d8>,
#  '而行': <gensim.models.keyedvectors.Vocab at 0x12c1c1710>,
#  '走时': <gensim.models.keyedvectors.Vocab at 0x12c1c1748>,
#  '停': <gensim.models.keyedvectors.Vocab at 0x12c1c1780>,
#  '坐': <gensim.models.keyedvectors.Vocab at 0x12c1c17b8>,
#  '躺': <gensim.models.keyedvectors.Vocab at 0x12c1c17f0>,
#  '险象环生': <gensim.models.keyedvectors.Vocab at 0x12c1c1828>,
#  '刘青停': <gensim.models.keyedvectors.Vocab at 0x12c1c1860>,
#  '好': <gensim.models.keyedvectors.Vocab at 0x12c1c1898>,
#  '另外': <gensim.models.keyedvectors.Vocab at 0x12c1c18d0>,
#  '一名': <gensim.models.keyedvectors.Vocab at 0x12c1c1908>,
#  '巡防': <gensim.models.keyedvectors.Vocab at 0x12c1c1940>,
#  '员': <gensim.models.keyedvectors.Vocab at 0x12c1c1978>,
#  '追': <gensim.models.keyedvectors.Vocab at 0x12c1c19b0>,
#  '上去': <gensim.models.keyedvectors.Vocab at 0x12c1c19e8>,
#  '情绪': <gensim.models.keyedvectors.Vocab at 0x12c1c1a20>,
#  '很': <gensim.models.keyedvectors.Vocab at 0x12c1c1a58>,
#  '低落': <gensim.models.keyedvectors.Vocab at 0x12c1c1a90>,
#  '话': <gensim.models.keyedvectors.Vocab at 0x12c1c1ac8>,
#  '不': <gensim.models.keyedvectors.Vocab at 0x12c1c1b00>,
#  '多': <gensim.models.keyedvectors.Vocab at 0x12c1c1b38>,
#  '尝试': <gensim.models.keyedvectors.Vocab at 0x12c1c1b70>,
#  '交流': <gensim.models.keyedvectors.Vocab at 0x12c1c1ba8>,
#  '离开': <gensim.models.keyedvectors.Vocab at 0x12c1c1be0>,
#  '可': <gensim.models.keyedvectors.Vocab at 0x12c1c1c18>,
#  '愿意': <gensim.models.keyedvectors.Vocab at 0x12c1c1c50>,
#  '接受': <gensim.models.keyedvectors.Vocab at 0x12c1c1c88>,
#  '继续': <gensim.models.keyedvectors.Vocab at 0x12c1c1cc0>,
#  '缓慢': <gensim.models.keyedvectors.Vocab at 0x12c1c1cf8>,
#  '地往': <gensim.models.keyedvectors.Vocab at 0x12c1c1d30>,
#  '快速路': <gensim.models.keyedvectors.Vocab at 0x12c1c1d68>,
#  '主干道': <gensim.models.keyedvectors.Vocab at 0x12c1c1da0>,
#  '走': <gensim.models.keyedvectors.Vocab at 0x12c1c1dd8>,
#  '此时': <gensim.models.keyedvectors.Vocab at 0x12c1c1e10>,
#  '路边': <gensim.models.keyedvectors.Vocab at 0x12c1c1e48>,
#  '聚集': <gensim.models.keyedvectors.Vocab at 0x12c1c1e80>,
#  '市民': <gensim.models.keyedvectors.Vocab at 0x12c1c1eb8>,
#  '围观': <gensim.models.keyedvectors.Vocab at 0x12c1c1ef0>,
#  '为了': <gensim.models.keyedvectors.Vocab at 0x12c1c1f28>,
#  '刺激': <gensim.models.keyedvectors.Vocab at 0x12c1c1f60>,
#  '一边': <gensim.models.keyedvectors.Vocab at 0x12c1c1f98>,
#  '盯': <gensim.models.keyedvectors.Vocab at 0x12c1c1fd0>,
#  '着': <gensim.models.keyedvectors.Vocab at 0x12c1c4048>,
#  '驱赶': <gensim.models.keyedvectors.Vocab at 0x12c1c4080>,
#  '群众': <gensim.models.keyedvectors.Vocab at 0x12c1c40b8>,
#  '从': <gensim.models.keyedvectors.Vocab at 0x12c1c40f0>,
#  '警方': <gensim.models.keyedvectors.Vocab at 0x12c1c4128>,
#  '提供': <gensim.models.keyedvectors.Vocab at 0x12c1c4160>,
#  '一份': <gensim.models.keyedvectors.Vocab at 0x12c1c4198>,
#  '视频': <gensim.models.keyedvectors.Vocab at 0x12c1c41d0>,
#  '了解': <gensim.models.keyedvectors.Vocab at 0x12c1c4208>,
#  '到': <gensim.models.keyedvectors.Vocab at 0x12c1c4240>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x12c1c4278>,
#  '出现': <gensim.models.keyedvectors.Vocab at 0x12c1c42b0>,
#  '坂雪岗': <gensim.models.keyedvectors.Vocab at 0x12c1c42e8>,
#  '监控': <gensim.models.keyedvectors.Vocab at 0x12c1c4320>,
#  '穿着': <gensim.models.keyedvectors.Vocab at 0x12c1c4358>,
#  '白色': <gensim.models.keyedvectors.Vocab at 0x12c1c4390>,
#  '内裤': <gensim.models.keyedvectors.Vocab at 0x12c1c43c8>,
#  '沿着': <gensim.models.keyedvectors.Vocab at 0x12c1c4400>,
#  '当时': <gensim.models.keyedvectors.Vocab at 0x12c1c4438>,
#  '正值': <gensim.models.keyedvectors.Vocab at 0x12c1c4470>,
#  '上班': <gensim.models.keyedvectors.Vocab at 0x12c1c44a8>,
#  '高峰期': <gensim.models.keyedvectors.Vocab at 0x12c1c44e0>,
#  '十字路口': <gensim.models.keyedvectors.Vocab at 0x12c1c4518>,
#  '排起': <gensim.models.keyedvectors.Vocab at 0x12c1c4550>,
#  '长队': <gensim.models.keyedvectors.Vocab at 0x12c1c4588>,
#  '当': <gensim.models.keyedvectors.Vocab at 0x12c1c45c0>,
#  '路上': <gensim.models.keyedvectors.Vocab at 0x12c1c45f8>,
#  '纷纷': <gensim.models.keyedvectors.Vocab at 0x12c1c4630>,
#  '驻足': <gensim.models.keyedvectors.Vocab at 0x12c1c4668>,
#  '观望': <gensim.models.keyedvectors.Vocab at 0x12c1c46a0>,
#  '不少': <gensim.models.keyedvectors.Vocab at 0x12c1c46d8>,
#  '车辆': <gensim.models.keyedvectors.Vocab at 0x12c1c4710>,
#  '放慢': <gensim.models.keyedvectors.Vocab at 0x12c1c4748>,
#  '速度': <gensim.models.keyedvectors.Vocab at 0x12c1c4780>,
#  '但': <gensim.models.keyedvectors.Vocab at 0x12c1c47b8>,
#  '停下': <gensim.models.keyedvectors.Vocab at 0x12c1c47f0>,
#  '脚步': <gensim.models.keyedvectors.Vocab at 0x12c1c4828>,
#  '依然': <gensim.models.keyedvectors.Vocab at 0x12c1c4860>,
#  '行进': <gensim.models.keyedvectors.Vocab at 0x12c1c4898>,
#  '中间': <gensim.models.keyedvectors.Vocab at 0x12c1c48d0>,
#  '一辆': <gensim.models.keyedvectors.Vocab at 0x12c1c4908>,
#  '货车': <gensim.models.keyedvectors.Vocab at 0x12c1c4940>,
#  '挡住': <gensim.models.keyedvectors.Vocab at 0x12c1c4978>,
#  '镜头': <gensim.models.keyedvectors.Vocab at 0x12c1c49b0>,
#  '但是': <gensim.models.keyedvectors.Vocab at 0x12c1c49e8>,
#  '再次出现': <gensim.models.keyedvectors.Vocab at 0x12c1c4a20>,
#  '没': <gensim.models.keyedvectors.Vocab at 0x12c1c4a58>,
#  '穿': <gensim.models.keyedvectors.Vocab at 0x12c1c4a90>,
#  '全身': <gensim.models.keyedvectors.Vocab at 0x12c1c4ac8>,
#  '裸露': <gensim.models.keyedvectors.Vocab at 0x12c1c4b00>,
#  '朝着': <gensim.models.keyedvectors.Vocab at 0x12c1c4b38>,
#  '周围': <gensim.models.keyedvectors.Vocab at 0x12c1c4b70>,
#  '没有': <gensim.models.keyedvectors.Vocab at 0x12c1c4ba8>,
#  '人': <gensim.models.keyedvectors.Vocab at 0x12c1c4be0>,
#  '尾随': <gensim.models.keyedvectors.Vocab at 0x12c1c4c18>,
#  '或者': <gensim.models.keyedvectors.Vocab at 0x12c1c4c50>,
#  '上前': <gensim.models.keyedvectors.Vocab at 0x12c1c4c88>,
#  '劝止': <gensim.models.keyedvectors.Vocab at 0x12c1c4cc0>,
#  '大清早': <gensim.models.keyedvectors.Vocab at 0x12c1c4cf8>,
#  '看到': <gensim.models.keyedvectors.Vocab at 0x12c1c4d30>,
#  '这样': <gensim.models.keyedvectors.Vocab at 0x12c1c4d68>,
#  '情况': <gensim.models.keyedvectors.Vocab at 0x12c1c4da0>,
#  '恐怕': <gensim.models.keyedvectors.Vocab at 0x12c1c4dd8>,
#  '大家': <gensim.models.keyedvectors.Vocab at 0x12c1c4e10>,
#  '办法': <gensim.models.keyedvectors.Vocab at 0x12c1c4e48>,
#  '淡定': <gensim.models.keyedvectors.Vocab at 0x12c1c4e80>,
#  '面对': <gensim.models.keyedvectors.Vocab at 0x12c1c4eb8>,
#  '这一': <gensim.models.keyedvectors.Vocab at 0x12c1c4ef0>,
#  '表示': <gensim.models.keyedvectors.Vocab at 0x12c1c4f28>,
#  '根本': <gensim.models.keyedvectors.Vocab at 0x12c1c4f60>,
#  '不敢': <gensim.models.keyedvectors.Vocab at 0x12c1c4f98>,
#  '看': <gensim.models.keyedvectors.Vocab at 0x12c1c4fd0>,
#  '心里': <gensim.models.keyedvectors.Vocab at 0x12c1c5048>,
#  '挺': <gensim.models.keyedvectors.Vocab at 0x12c1c5080>,
#  '别扭': <gensim.models.keyedvectors.Vocab at 0x12c1c50b8>,
#  '感觉': <gensim.models.keyedvectors.Vocab at 0x12c1c50f0>,
#  '尴尬': <gensim.models.keyedvectors.Vocab at 0x12c1c5128>,
#  '跟随': <gensim.models.keyedvectors.Vocab at 0x12c1c5160>,
#  '作出': <gensim.models.keyedvectors.Vocab at 0x12c1c5198>,
#  '让': <gensim.models.keyedvectors.Vocab at 0x12c1c51d0>,
#  '意想不到': <gensim.models.keyedvectors.Vocab at 0x12c1c5208>,
#  '举动': <gensim.models.keyedvectors.Vocab at 0x12c1c5240>,
#  '突然': <gensim.models.keyedvectors.Vocab at 0x12c1c5278>,
#  '靠近': <gensim.models.keyedvectors.Vocab at 0x12c1c52b0>,
#  '护栏': <gensim.models.keyedvectors.Vocab at 0x12c1c52e8>,
#  '上面': <gensim.models.keyedvectors.Vocab at 0x12c1c5320>,
#  '跳下去': <gensim.models.keyedvectors.Vocab at 0x12c1c5358>,
#  '赶忙': <gensim.models.keyedvectors.Vocab at 0x12c1c5390>,
#  '冲上去': <gensim.models.keyedvectors.Vocab at 0x12c1c53c8>,
#  '拉住': <gensim.models.keyedvectors.Vocab at 0x12c1c5400>,
#  '手': <gensim.models.keyedvectors.Vocab at 0x12c1c5438>,
#  '控制': <gensim.models.keyedvectors.Vocab at 0x12c1c5470>,
#  '住': <gensim.models.keyedvectors.Vocab at 0x12c1c54a8>,
#  '远离': <gensim.models.keyedvectors.Vocab at 0x12c1c54e0>,
#  '碍于': <gensim.models.keyedvectors.Vocab at 0x12c1c5518>,
#  '穿衣服': <gensim.models.keyedvectors.Vocab at 0x12c1c5550>,
#  '刘青递': <gensim.models.keyedvectors.Vocab at 0x12c1c5588>,
#  '衣服': <gensim.models.keyedvectors.Vocab at 0x12c1c55c0>,
#  '把': <gensim.models.keyedvectors.Vocab at 0x12c1c55f8>,
#  '扔': <gensim.models.keyedvectors.Vocab at 0x12c1c5630>,
#  '排水沟': <gensim.models.keyedvectors.Vocab at 0x12c1c5668>,
#  '里': <gensim.models.keyedvectors.Vocab at 0x12c1c56a0>,
#  '往前走': <gensim.models.keyedvectors.Vocab at 0x12c1c56d8>,
#  '只能': <gensim.models.keyedvectors.Vocab at 0x12c1c5710>,
#  '紧紧': <gensim.models.keyedvectors.Vocab at 0x12c1c5748>,
#  '拉': <gensim.models.keyedvectors.Vocab at 0x12c1c5780>,
#  '一只': <gensim.models.keyedvectors.Vocab at 0x12c1c57b8>,
#  '跟': <gensim.models.keyedvectors.Vocab at 0x12c1c57f0>,
#  '后面': <gensim.models.keyedvectors.Vocab at 0x12c1c5828>,
#  '一路上': <gensim.models.keyedvectors.Vocab at 0x12c1c5860>,
#  '耐心': <gensim.models.keyedvectors.Vocab at 0x12c1c5898>,
#  '开导': <gensim.models.keyedvectors.Vocab at 0x12c1c58d0>,
#  '安慰': <gensim.models.keyedvectors.Vocab at 0x12c1c5908>,
#  '听到': <gensim.models.keyedvectors.Vocab at 0x12c1c5940>,
#  '不断': <gensim.models.keyedvectors.Vocab at 0x12c1c5978>,
#  '重复': <gensim.models.keyedvectors.Vocab at 0x12c1c59b0>,
#  '一句': <gensim.models.keyedvectors.Vocab at 0x12c1c59e8>,
#  '要是': <gensim.models.keyedvectors.Vocab at 0x12c1c5a20>,
#  '你': <gensim.models.keyedvectors.Vocab at 0x12c1c5a58>,
#  '遭遇': <gensim.models.keyedvectors.Vocab at 0x12c1c5a90>,
#  '我': <gensim.models.keyedvectors.Vocab at 0x12c1c5ac8>,
#  '事': <gensim.models.keyedvectors.Vocab at 0x12c1c5b00>,
#  '会': <gensim.models.keyedvectors.Vocab at 0x12c1c5b38>,
#  '不时': <gensim.models.keyedvectors.Vocab at 0x12c1c5b70>,
#  '试图': <gensim.models.keyedvectors.Vocab at 0x12c1c5ba8>,
#  '挣脱': <gensim.models.keyedvectors.Vocab at 0x12c1c5be0>,
#  '手要': <gensim.models.keyedvectors.Vocab at 0x12c1c5c18>,
#  '冲向': <gensim.models.keyedvectors.Vocab at 0x12c1c5c50>,
#  '往下跳': <gensim.models.keyedvectors.Vocab at 0x12c1c5c88>,
#  '就': <gensim.models.keyedvectors.Vocab at 0x12c1c5cc0>,
#  '牵': <gensim.models.keyedvectors.Vocab at 0x12c1c5cf8>,
#  '天': <gensim.models.keyedvectors.Vocab at 0x12c1c5d30>,
#  '下起': <gensim.models.keyedvectors.Vocab at 0x12c1c5d68>,
#  '大暴雨': <gensim.models.keyedvectors.Vocab at 0x12c1c5da0>,
#  '雨大': <gensim.models.keyedvectors.Vocab at 0x12c1c5dd8>,
#  '连': <gensim.models.keyedvectors.Vocab at 0x12c1c5e10>,
#  '眼睛': <gensim.models.keyedvectors.Vocab at 0x12c1c5e48>,
#  '睁不开': <gensim.models.keyedvectors.Vocab at 0x12c1c5e80>,
#  '说': <gensim.models.keyedvectors.Vocab at 0x12c1c5eb8>,
#  '瞬间': <gensim.models.keyedvectors.Vocab at 0x12c1c5ef0>,
#  '雨': <gensim.models.keyedvectors.Vocab at 0x12c1c5f28>,
#  '透': <gensim.models.keyedvectors.Vocab at 0x12c1c5f60>,
#  '帮助': <gensim.models.keyedvectors.Vocab at 0x12c1c5f98>,
#  '冒': <gensim.models.keyedvectors.Vocab at 0x12c1c5fd0>,
#  '大雨': <gensim.models.keyedvectors.Vocab at 0x12c1c8048>,
#  '四十分钟': <gensim.models.keyedvectors.Vocab at 0x12c1c8080>,
#  '吧': <gensim.models.keyedvectors.Vocab at 0x12c1c80b8>,
#  '来说': <gensim.models.keyedvectors.Vocab at 0x12c1c80f0>,
#  '想': <gensim.models.keyedvectors.Vocab at 0x12c1c8128>,
#  '回家': <gensim.models.keyedvectors.Vocab at 0x12c1c8160>,
#  '然后': <gensim.models.keyedvectors.Vocab at 0x12c1c8198>,
#  '递过来': <gensim.models.keyedvectors.Vocab at 0x12c1c81d0>,
#  '微博上': <gensim.models.keyedvectors.Vocab at 0x12c1c8208>,
#  '照片': <gensim.models.keyedvectors.Vocab at 0x12c1c8240>,
#  '披着': <gensim.models.keyedvectors.Vocab at 0x12c1c8278>,
#  '小心翼翼': <gensim.models.keyedvectors.Vocab at 0x12c1c82b0>,
#  '旁边': <gensim.models.keyedvectors.Vocab at 0x12c1c82e8>,
#  '场景': <gensim.models.keyedvectors.Vocab at 0x12c1c8320>,
#  '南平': <gensim.models.keyedvectors.Vocab at 0x12c1c8358>,
#  '下来': <gensim.models.keyedvectors.Vocab at 0x12c1c8390>,
#  '带到': <gensim.models.keyedvectors.Vocab at 0x12c1c83c8>,
#  '派出所': <gensim.models.keyedvectors.Vocab at 0x12c1c8400>,
#  '那': <gensim.models.keyedvectors.Vocab at 0x12c1c8438>,
#  '姑娘': <gensim.models.keyedvectors.Vocab at 0x12c1c8470>,
#  '什么样': <gensim.models.keyedvectors.Vocab at 0x12c1c84a8>,
#  '事情': <gensim.models.keyedvectors.Vocab at 0x12c1c84e0>,
#  '才': <gensim.models.keyedvectors.Vocab at 0x12c1c8518>,
#  '据': <gensim.models.keyedvectors.Vocab at 0x12c1c8550>,
#  '透露': <gensim.models.keyedvectors.Vocab at 0x12c1c8588>,
#  '姓': <gensim.models.keyedvectors.Vocab at 0x12c1c85c0>,
#  '陈': <gensim.models.keyedvectors.Vocab at 0x12c1c85f8>,
#  '系': <gensim.models.keyedvectors.Vocab at 0x12c1c8630>,
#  '湖北': <gensim.models.keyedvectors.Vocab at 0x12c1c8668>,
#  '家属': <gensim.models.keyedvectors.Vocab at 0x12c1c86a0>,
#  '反映': <gensim.models.keyedvectors.Vocab at 0x12c1c86d8>,
#  '其有': <gensim.models.keyedvectors.Vocab at 0x12c1c8710>,
#  '精神病': <gensim.models.keyedvectors.Vocab at 0x12c1c8748>,
#  '史': <gensim.models.keyedvectors.Vocab at 0x12c1c8780>,
#  '三天': <gensim.models.keyedvectors.Vocab at 0x12c1c87b8>,
#  '前': <gensim.models.keyedvectors.Vocab at 0x12c1c87f0>,
#  '陈某': <gensim.models.keyedvectors.Vocab at 0x12c1c8828>,
#  '老家': <gensim.models.keyedvectors.Vocab at 0x12c1c8860>,
#  '来': <gensim.models.keyedvectors.Vocab at 0x12c1c8898>,
#  '受挫': <gensim.models.keyedvectors.Vocab at 0x12c1c88d0>,
#  '导致': <gensim.models.keyedvectors.Vocab at 0x12c1c8908>,
#  '异常': <gensim.models.keyedvectors.Vocab at 0x12c1c8940>,
#  '遂': <gensim.models.keyedvectors.Vocab at 0x12c1c8978>,
#  '产生': <gensim.models.keyedvectors.Vocab at 0x12c1c89b0>,
#  '念头': <gensim.models.keyedvectors.Vocab at 0x12c1c89e8>,
#  '送往': <gensim.models.keyedvectors.Vocab at 0x12c1c8a20>,
#  '某': <gensim.models.keyedvectors.Vocab at 0x12c1c8a58>,
#  '医院': <gensim.models.keyedvectors.Vocab at 0x12c1c8a90>,
#  '治疗': <gensim.models.keyedvectors.Vocab at 0x12c1c8ac8>,
#  '大大': <gensim.models.keyedvectors.Vocab at 0x12c1c8b00>,
#  '君': <gensim.models.keyedvectors.Vocab at 0x12c1c8b38>,
#  '希望': <gensim.models.keyedvectors.Vocab at 0x12c1c8b70>,
#  '早点': <gensim.models.keyedvectors.Vocab at 0x12c1c8ba8>,
#  '康复': <gensim.models.keyedvectors.Vocab at 0x12c1c8be0>,
#  '其实': <gensim.models.keyedvectors.Vocab at 0x12c1c8c18>,
#  '真爱': <gensim.models.keyedvectors.Vocab at 0x12c1c8c50>,
#  '到来': <gensim.models.keyedvectors.Vocab at 0x12c1c8c88>,
#  '存在': <gensim.models.keyedvectors.Vocab at 0x12c1c8cc0>,
#  '年龄': <gensim.models.keyedvectors.Vocab at 0x12c1c8cf8>,
#  '限制': <gensim.models.keyedvectors.Vocab at 0x12c1c8d30>,
#  '你们': <gensim.models.keyedvectors.Vocab at 0x12c1c8d68>,
#  '因': <gensim.models.keyedvectors.Vocab at 0x12c1c8da0>,
#  '善良': <gensim.models.keyedvectors.Vocab at 0x12c1c8dd8>,
#  '原因': <gensim.models.keyedvectors.Vocab at 0x12c1c8e10>,
#  '一众': <gensim.models.keyedvectors.Vocab at 0x12c1c8e48>,
#  '暖': <gensim.models.keyedvectors.Vocab at 0x12c1c8e80>,
#  '男点': <gensim.models.keyedvectors.Vocab at 0x12c1c8eb8>,
#  'ZAN': <gensim.models.keyedvectors.Vocab at 0x12c1c8ef0>,
#  '弓常': <gensim.models.keyedvectors.Vocab at 0x12c1c8f28>,
#  'yan': <gensim.models.keyedvectors.Vocab at 0x12c1c8f60>,
#  '桦': <gensim.models.keyedvectors.Vocab at 0x12c1c8f98>,
#  '问': <gensim.models.keyedvectors.Vocab at 0x12c1c8fd0>,
#  '这个': <gensim.models.keyedvectors.Vocab at 0x12c1ca048>,
#  '哥哥': <gensim.models.keyedvectors.Vocab at 0x12c1ca080>,
#  '女票': <gensim.models.keyedvectors.Vocab at 0x12c1ca0b8>,
#  '吗': <gensim.models.keyedvectors.Vocab at 0x12c1ca0f0>,
#  '原谅': <gensim.models.keyedvectors.Vocab at 0x12c1ca128>,
#  '一辈子': <gensim.models.keyedvectors.Vocab at 0x12c1ca160>,
#  '浪荡': <gensim.models.keyedvectors.Vocab at 0x12c1ca198>,
#  '不羁': <gensim.models.keyedvectors.Vocab at 0x12c1ca1d0>,
#  '爱': <gensim.models.keyedvectors.Vocab at 0x12c1ca208>,
#  '萨摩耶': <gensim.models.keyedvectors.Vocab at 0x12c1ca240>,
#  '过不去': <gensim.models.keyedvectors.Vocab at 0x12c1ca278>,
#  '嘛': <gensim.models.keyedvectors.Vocab at 0x12c1ca2b0>,
#  '想想': <gensim.models.keyedvectors.Vocab at 0x12c1ca2e8>,
#  '自己': <gensim.models.keyedvectors.Vocab at 0x12c1ca320>,
#  '家人': <gensim.models.keyedvectors.Vocab at 0x12c1ca358>,
#  '同时': <gensim.models.keyedvectors.Vocab at 0x12c1ca390>,
#  '感谢': <gensim.models.keyedvectors.Vocab at 0x12c1ca3c8>,
#  '蜀黍': <gensim.models.keyedvectors.Vocab at 0x12c1ca400>,
#  '火心': <gensim.models.keyedvectors.Vocab at 0x12c1ca438>,
#  '聆听': <gensim.models.keyedvectors.Vocab at 0x12c1ca470>,
#  '心灵': <gensim.models.keyedvectors.Vocab at 0x12c1ca4a8>,
#  '点赞': <gensim.models.keyedvectors.Vocab at 0x12c1ca4e0>,
#  '中華云盾': <gensim.models.keyedvectors.Vocab at 0x12c1ca518>,
#  '警察': <gensim.models.keyedvectors.Vocab at 0x12c1ca550>,
#  '就是': <gensim.models.keyedvectors.Vocab at 0x12c1ca588>,
#  '需时': <gensim.models.keyedvectors.Vocab at 0x12c1ca5c0>,
#  '申出': <gensim.models.keyedvectors.Vocab at 0x12c1ca5f8>,
#  '援手': <gensim.models.keyedvectors.Vocab at 0x12c1ca630>,
#  'Tomchlee': <gensim.models.keyedvectors.Vocab at 0x12c1ca668>,
#  '帅': <gensim.models.keyedvectors.Vocab at 0x12c1ca6a0>,
#  '！': <gensim.models.keyedvectors.Vocab at 0x12c1ca6d8>,
#  'SJ': <gensim.models.keyedvectors.Vocab at 0x12c1ca710>,
#  '李赫海': <gensim.models.keyedvectors.Vocab at 0x12c1ca748>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x12c1ca780>,
#  '木有': <gensim.models.keyedvectors.Vocab at 0x12c1ca7b8>,
#  '男子': <gensim.models.keyedvectors.Vocab at 0x12c1ca7f0>,
#  '迷奸': <gensim.models.keyedvectors.Vocab at 0x12c1ca828>,
#  '拍': <gensim.models.keyedvectors.Vocab at 0x12c1ca860>,
#  '418': <gensim.models.keyedvectors.Vocab at 0x12c1ca898>,
#  '女方': <gensim.models.keyedvectors.Vocab at 0x12c1ca8d0>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x12c1ca908>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x12c1ca940>,
#  '号': <gensim.models.keyedvectors.Vocab at 0x12c1ca978>,
#  '上午': <gensim.models.keyedvectors.Vocab at 0x12c1ca9b0>,
#  '淮安市': <gensim.models.keyedvectors.Vocab at 0x12c1ca9e8>,
#  '涟水县': <gensim.models.keyedvectors.Vocab at 0x12c1caa20>,
#  '公安局': <gensim.models.keyedvectors.Vocab at 0x12c1caa58>,
#  '刑警大队': <gensim.models.keyedvectors.Vocab at 0x12c1caa90>,
#  '一个': <gensim.models.keyedvectors.Vocab at 0x12c1caac8>,
#  '奇怪': <gensim.models.keyedvectors.Vocab at 0x12c1cab00>,
#  '报警': <gensim.models.keyedvectors.Vocab at 0x12c1cab38>,
#  '电话': <gensim.models.keyedvectors.Vocab at 0x12c1cab70>,
#  '言语': <gensim.models.keyedvectors.Vocab at 0x12c1caba8>,
#  '不清': <gensim.models.keyedvectors.Vocab at 0x12c1cabe0>,
#  '声称': <gensim.models.keyedvectors.Vocab at 0x12c1cac18>,
#  '遭到': <gensim.models.keyedvectors.Vocab at 0x12c1cac50>,
#  '侵害': <gensim.models.keyedvectors.Vocab at 0x12c1cac88>,
#  '几个': <gensim.models.keyedvectors.Vocab at 0x12c1cacc0>,
#  '关键词': <gensim.models.keyedvectors.Vocab at 0x12c1cacf8>,
#  '令': <gensim.models.keyedvectors.Vocab at 0x12c1cad30>,
#  '民警': <gensim.models.keyedvectors.Vocab at 0x12c1cad68>,
#  '紧张': <gensim.models.keyedvectors.Vocab at 0x12c1cada0>,
#  '起来': <gensim.models.keyedvectors.Vocab at 0x12c1cadd8>,
#  '受到': <gensim.models.keyedvectors.Vocab at 0x12c1cae10>,
#  'A股': <gensim.models.keyedvectors.Vocab at 0x12c1cae48>,
#  '纳入': <gensim.models.keyedvectors.Vocab at 0x12c1cae80>,
#  'MSCI': <gensim.models.keyedvectors.Vocab at 0x12c1caeb8>,
#  '指数': <gensim.models.keyedvectors.Vocab at 0x12c1caef0>,
#  '利好': <gensim.models.keyedvectors.Vocab at 0x12c1caf28>,
#  '消息': <gensim.models.keyedvectors.Vocab at 0x12c1caf60>,
#  '市场': <gensim.models.keyedvectors.Vocab at 0x12c1caf98>,
#  '周三': <gensim.models.keyedvectors.Vocab at 0x12c1cafd0>,
#  '再度': <gensim.models.keyedvectors.Vocab at 0x12c1cc048>,
#  '上演': <gensim.models.keyedvectors.Vocab at 0x12c1cc080>,
#  '龙马': <gensim.models.keyedvectors.Vocab at 0x12c1cc0b8>,
#  '行情': <gensim.models.keyedvectors.Vocab at 0x12c1cc0f0>,
#  '周四': <gensim.models.keyedvectors.Vocab at 0x12c1cc128>,
#  '金融股': <gensim.models.keyedvectors.Vocab at 0x12c1cc160>,
#  '白马股': <gensim.models.keyedvectors.Vocab at 0x12c1cc198>,
#  '表现': <gensim.models.keyedvectors.Vocab at 0x12c1cc1d0>,
#  '喜人': <gensim.models.keyedvectors.Vocab at 0x12c1cc208>,
#  '尾盘': <gensim.models.keyedvectors.Vocab at 0x12c1cc240>,
#  '跳水': <gensim.models.keyedvectors.Vocab at 0x12c1cc278>,
#  '之后': <gensim.models.keyedvectors.Vocab at 0x12c1cc2b0>,
#  '仅': <gensim.models.keyedvectors.Vocab at 0x12c1cc2e8>,
#  '金融': <gensim.models.keyedvectors.Vocab at 0x12c1cc320>,
#  '板块': <gensim.models.keyedvectors.Vocab at 0x12c1cc358>,
#  '仍': <gensim.models.keyedvectors.Vocab at 0x12c1cc390>,
#  '维系': <gensim.models.keyedvectors.Vocab at 0x12c1cc3c8>,
#  '红盘': <gensim.models.keyedvectors.Vocab at 0x12c1cc400>,
#  '状态': <gensim.models.keyedvectors.Vocab at 0x12c1cc438>,
#  '分析': <gensim.models.keyedvectors.Vocab at 0x12c1cc470>,
#  '人士': <gensim.models.keyedvectors.Vocab at 0x12c1cc4a8>,
#  '认为': <gensim.models.keyedvectors.Vocab at 0x12c1cc4e0>,
#  '受益': <gensim.models.keyedvectors.Vocab at 0x12c1cc518>,
#  '于': <gensim.models.keyedvectors.Vocab at 0x12c1cc550>,
#  '低': <gensim.models.keyedvectors.Vocab at 0x12c1cc588>,
#  '估值': <gensim.models.keyedvectors.Vocab at 0x12c1cc5c0>,
#  '重获': <gensim.models.keyedvectors.Vocab at 0x12c1cc5f8>,
#  '资金': <gensim.models.keyedvectors.Vocab at 0x12c1cc630>,
#  '青睐': <gensim.models.keyedvectors.Vocab at 0x12c1cc668>,
#  '存量': <gensim.models.keyedvectors.Vocab at 0x12c1cc6a0>,
#  '博弈': <gensim.models.keyedvectors.Vocab at 0x12c1cc6d8>,
#  '格局': <gensim.models.keyedvectors.Vocab at 0x12c1cc710>,
#  '下': <gensim.models.keyedvectors.Vocab at 0x12c1cc748>,
#  '风格': <gensim.models.keyedvectors.Vocab at 0x12c1cc780>,
#  '交替': <gensim.models.keyedvectors.Vocab at 0x12c1cc7b8>,
#  '震荡': <gensim.models.keyedvectors.Vocab at 0x12c1cc7f0>,
#  '料': <gensim.models.keyedvectors.Vocab at 0x12c1cc828>,
#  '延续': <gensim.models.keyedvectors.Vocab at 0x12c1cc860>,
#  '流动性': <gensim.models.keyedvectors.Vocab at 0x12c1cc898>,
#  '改善': <gensim.models.keyedvectors.Vocab at 0x12c1cc8d0>,
#  '经济': <gensim.models.keyedvectors.Vocab at 0x12c1cc908>,
#  '悲观': <gensim.models.keyedvectors.Vocab at 0x12c1cc940>,
#  '预期': <gensim.models.keyedvectors.Vocab at 0x12c1cc978>,
#  '修正': <gensim.models.keyedvectors.Vocab at 0x12c1cc9b0>,
#  '有助于': <gensim.models.keyedvectors.Vocab at 0x12c1cc9e8>,
#  '支撑': <gensim.models.keyedvectors.Vocab at 0x12c1cca20>,
#  '继而': <gensim.models.keyedvectors.Vocab at 0x12c1cca58>,
#  '大盘': <gensim.models.keyedvectors.Vocab at 0x12c1cca90>,
#  '逐步': <gensim.models.keyedvectors.Vocab at 0x12c1ccac8>,
#  '向': <gensim.models.keyedvectors.Vocab at 0x12c1ccb00>,
#  '九': <gensim.models.keyedvectors.Vocab at 0x12c1ccb38>,
#  '再现': <gensim.models.keyedvectors.Vocab at 0x12c1ccb70>,
#  '未能': <gensim.models.keyedvectors.Vocab at 0x12c1ccba8>,
#  '上行': <gensim.models.keyedvectors.Vocab at 0x12c1ccbe0>,
#  '态势': <gensim.models.keyedvectors.Vocab at 0x12c1ccc18>,
#  '两市': <gensim.models.keyedvectors.Vocab at 0x12c1ccc50>,
#  '成交': <gensim.models.keyedvectors.Vocab at 0x12c1ccc88>,
#  '小幅': <gensim.models.keyedvectors.Vocab at 0x12c1cccc0>,
#  '放量': <gensim.models.keyedvectors.Vocab at 0x12c1cccf8>,
#  '29': <gensim.models.keyedvectors.Vocab at 0x12c1ccd30>,
#  '中信': <gensim.models.keyedvectors.Vocab at 0x12c1ccd68>,
#  '一级': <gensim.models.keyedvectors.Vocab at 0x12c1ccda0>,
#  '行业': <gensim.models.keyedvectors.Vocab at 0x12c1ccdd8>,
#  '收盘': <gensim.models.keyedvectors.Vocab at 0x12c1cce10>,
#  '银行': <gensim.models.keyedvectors.Vocab at 0x12c1cce48>,
#  '非银行': <gensim.models.keyedvectors.Vocab at 0x12c1cce80>,
#  '两个': <gensim.models.keyedvectors.Vocab at 0x12c1cceb8>,
#  '收红': <gensim.models.keyedvectors.Vocab at 0x12c1ccef0>,
#  '分别': <gensim.models.keyedvectors.Vocab at 0x12c1ccf28>,
#  '上涨': <gensim.models.keyedvectors.Vocab at 0x12c1ccf60>,
#  '1.80%': <gensim.models.keyedvectors.Vocab at 0x12c1ccf98>,
#  '0.20%': <gensim.models.keyedvectors.Vocab at 0x12c1ccfd0>,
#  '二级': <gensim.models.keyedvectors.Vocab at 0x12c1cf048>,
#  '来看': <gensim.models.keyedvectors.Vocab at 0x12c1cf080>,
#  '股份制': <gensim.models.keyedvectors.Vocab at 0x12c1cf0b8>,
#  '城商行': <gensim.models.keyedvectors.Vocab at 0x12c1cf0f0>,
#  '涨幅': <gensim.models.keyedvectors.Vocab at 0x12c1cf128>,
#  '最高': <gensim.models.keyedvectors.Vocab at 0x12c1cf160>,
#  '达到': <gensim.models.keyedvectors.Vocab at 0x12c1cf198>,
#  '2.22%': <gensim.models.keyedvectors.Vocab at 0x12c1cf1d0>,
#  '国有银行': <gensim.models.keyedvectors.Vocab at 0x12c1cf208>,
#  '0.82%': <gensim.models.keyedvectors.Vocab at 0x12c1cf240>,
#  '信托': <gensim.models.keyedvectors.Vocab at 0x12c1cf278>,
#  '及其': <gensim.models.keyedvectors.Vocab at 0x12c1cf2b0>,
#  '0.64%': <gensim.models.keyedvectors.Vocab at 0x12c1cf2e8>,
#  '保险': <gensim.models.keyedvectors.Vocab at 0x12c1cf320>,
#  '0.34%': <gensim.models.keyedvectors.Vocab at 0x12c1cf358>,
#  '证券': <gensim.models.keyedvectors.Vocab at 0x12c1cf390>,
#  '0.06%': <gensim.models.keyedvectors.Vocab at 0x12c1cf3c8>,
#  '成分股': <gensim.models.keyedvectors.Vocab at 0x12c1cf400>,
#  '共有': <gensim.models.keyedvectors.Vocab at 0x12c1cf438>,
#  '21': <gensim.models.keyedvectors.Vocab at 0x12c1cf470>,
#  '其中': <gensim.models.keyedvectors.Vocab at 0x12c1cf4a8>,
#  '招商银行': <gensim.models.keyedvectors.Vocab at 0x12c1cf4e0>,
#  '最大': <gensim.models.keyedvectors.Vocab at 0x12c1cf518>,
#  '6.66%': <gensim.models.keyedvectors.Vocab at 0x12c1cf550>,
#  '贵阳': <gensim.models.keyedvectors.Vocab at 0x12c1cf588>,
#  '3.65%': <gensim.models.keyedvectors.Vocab at 0x12c1cf5c0>,
#  '上海银行': <gensim.models.keyedvectors.Vocab at 0x12c1cf5f8>,
#  '华夏银行': <gensim.models.keyedvectors.Vocab at 0x12c1cf630>,
#  '浦发银行': <gensim.models.keyedvectors.Vocab at 0x12c1cf668>,
#  '兴业银行': <gensim.models.keyedvectors.Vocab at 0x12c1cf6a0>,
#  '超过': <gensim.models.keyedvectors.Vocab at 0x12c1cf6d8>,
#  '1.50%': <gensim.models.keyedvectors.Vocab at 0x12c1cf710>,
#  '共': <gensim.models.keyedvectors.Vocab at 0x12c1cf748>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x12c1cf780>,
#  '个股': <gensim.models.keyedvectors.Vocab at 0x12c1cf7b8>,
#  '安信': <gensim.models.keyedvectors.Vocab at 0x12c1cf7f0>,
#  '中国': <gensim.models.keyedvectors.Vocab at 0x12c1cf828>,
#  '太保': <gensim.models.keyedvectors.Vocab at 0x12c1cf860>,
#  '居前': <gensim.models.keyedvectors.Vocab at 0x12c1cf898>,
#  '两名': <gensim.models.keyedvectors.Vocab at 0x12c1cf8d0>,
#  '4.57%': <gensim.models.keyedvectors.Vocab at 0x12c1cf908>,
#  '3.04%': <gensim.models.keyedvectors.Vocab at 0x12c1cf940>,
#  '西水股份': <gensim.models.keyedvectors.Vocab at 0x12c1cf978>,
#  '华安': <gensim.models.keyedvectors.Vocab at 0x12c1cf9b0>,
#  '人寿': <gensim.models.keyedvectors.Vocab at 0x12c1cf9e8>,
#  '新华': <gensim.models.keyedvectors.Vocab at 0x12c1cfa20>,
#  '2%': <gensim.models.keyedvectors.Vocab at 0x12c1cfa58>,
#  '相对而言': <gensim.models.keyedvectors.Vocab at 0x12c1cfa90>,
#  '券商': <gensim.models.keyedvectors.Vocab at 0x12c1cfac8>,
#  '股多': <gensim.models.keyedvectors.Vocab at 0x12c1cfb00>,
#  '下跌': <gensim.models.keyedvectors.Vocab at 0x12c1cfb38>,
#  '近期': <gensim.models.keyedvectors.Vocab at 0x12c1cfb70>,
#  '对': <gensim.models.keyedvectors.Vocab at 0x12c1cfba8>,
#  '消息面': <gensim.models.keyedvectors.Vocab at 0x12c1cfbe0>,
#  '宣布': <gensim.models.keyedvectors.Vocab at 0x12c1cfc18>,
#  '2018': <gensim.models.keyedvectors.Vocab at 0x12c1cfc50>,
#  '年': <gensim.models.keyedvectors.Vocab at 0x12c1cfc88>,
#  '新兴': <gensim.models.keyedvectors.Vocab at 0x12c1cfcc0>,
#  '占': <gensim.models.keyedvectors.Vocab at 0x12c1cfcf8>,
#  '群体': <gensim.models.keyedvectors.Vocab at 0x12c1cfd30>,
#  '国金': <gensim.models.keyedvectors.Vocab at 0x12c1cfd68>,
#  '李立峰': <gensim.models.keyedvectors.Vocab at 0x12c1cfda0>,
#  '团队': <gensim.models.keyedvectors.Vocab at 0x12c1cfdd8>,
#  '指出': <gensim.models.keyedvectors.Vocab at 0x12c1cfe10>,
#  '最新': <gensim.models.keyedvectors.Vocab at 0x12c1cfe48>,
#  '包含': <gensim.models.keyedvectors.Vocab at 0x12c1cfe80>,
#  '222': <gensim.models.keyedvectors.Vocab at 0x12c1cfeb8>,
#  '剔除': <gensim.models.keyedvectors.Vocab at 0x12c1cfef0>,
#  '中等': <gensim.models.keyedvectors.Vocab at 0x12c1cff28>,
#  '市值': <gensim.models.keyedvectors.Vocab at 0x12c1cff60>,
#  '非': <gensim.models.keyedvectors.Vocab at 0x12c1cff98>,
#  '互联互通': <gensim.models.keyedvectors.Vocab at 0x12c1cffd0>,
#  '交易': <gensim.models.keyedvectors.Vocab at 0x12c1d1048>,
#  '股票': <gensim.models.keyedvectors.Vocab at 0x12c1d1080>,
#  '以及': <gensim.models.keyedvectors.Vocab at 0x12c1d10b8>,
#  '停牌': <gensim.models.keyedvectors.Vocab at 0x12c1d10f0>,
#  '标的': <gensim.models.keyedvectors.Vocab at 0x12c1d1128>,
#  '由于': <gensim.models.keyedvectors.Vocab at 0x12c1d1160>,
#  '很多': <gensim.models.keyedvectors.Vocab at 0x12c1d1198>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x12c1d11d0>,
#  'H股': <gensim.models.keyedvectors.Vocab at 0x12c1d1208>,
#  'EM': <gensim.models.keyedvectors.Vocab at 0x12c1d1240>,
#  '权重': <gensim.models.keyedvectors.Vocab at 0x12c1d1278>,
#  '由': <gensim.models.keyedvectors.Vocab at 0x12c1d12b0>,
#  '0.5%': <gensim.models.keyedvectors.Vocab at 0x12c1d12e8>,
#  '上升': <gensim.models.keyedvectors.Vocab at 0x12c1d1320>,
#  '0.73%': <gensim.models.keyedvectors.Vocab at 0x12c1d1358>,
#  '40.11%': <gensim.models.keyedvectors.Vocab at 0x12c1d1390>,
#  '泛': <gensim.models.keyedvectors.Vocab at 0x12c1d13c8>,
#  '消费': <gensim.models.keyedvectors.Vocab at 0x12c1d1400>,
#  '次之': <gensim.models.keyedvectors.Vocab at 0x12c1d1438>,
#  '24.26%': <gensim.models.keyedvectors.Vocab at 0x12c1d1470>,
#  '涵盖': <gensim.models.keyedvectors.Vocab at 0x12c1d14a8>,
#  '大部分': <gensim.models.keyedvectors.Vocab at 0x12c1d14e0>,
#  '权重股': <gensim.models.keyedvectors.Vocab at 0x12c1d1518>,
#  '动态': <gensim.models.keyedvectors.Vocab at 0x12c1d1550>,
#  '加入': <gensim.models.keyedvectors.Vocab at 0x12c1d1588>,
#  '指': <gensim.models.keyedvectors.Vocab at 0x12c1d15c0>,
#  '比高': <gensim.models.keyedvectors.Vocab at 0x12c1d15f8>,
#  '金融公司': <gensim.models.keyedvectors.Vocab at 0x12c1d1630>,
#  '增加': <gensim.models.keyedvectors.Vocab at 0x12c1d1668>,
#  '近一半': <gensim.models.keyedvectors.Vocab at 0x12c1d16a0>,
#  '其他': <gensim.models.keyedvectors.Vocab at 0x12c1d16d8>,
#  '稀释': <gensim.models.keyedvectors.Vocab at 0x12c1d1710>,
#  '尽管': <gensim.models.keyedvectors.Vocab at 0x12c1d1748>,
#  '事件': <gensim.models.keyedvectors.Vocab at 0x12c1d1780>,
#  '短期': <gensim.models.keyedvectors.Vocab at 0x12c1d17b8>,
#  '有所': <gensim.models.keyedvectors.Vocab at 0x12c1d17f0>,
#  '提振': <gensim.models.keyedvectors.Vocab at 0x12c1d1828>,
#  '中长期': <gensim.models.keyedvectors.Vocab at 0x12c1d1860>,
#  '海外': <gensim.models.keyedvectors.Vocab at 0x12c1d1898>,
#  '增量': <gensim.models.keyedvectors.Vocab at 0x12c1d18d0>,
#  '升温': <gensim.models.keyedvectors.Vocab at 0x12c1d1908>,
#  '短期内': <gensim.models.keyedvectors.Vocab at 0x12c1d1940>,
#  '尚': <gensim.models.keyedvectors.Vocab at 0x12c1d1978>,
#  '不能': <gensim.models.keyedvectors.Vocab at 0x12c1d19b0>,
#  '有效': <gensim.models.keyedvectors.Vocab at 0x12c1d19e8>,
#  '放大': <gensim.models.keyedvectors.Vocab at 0x12c1d1a20>,
#  '独': <gensim.models.keyedvectors.Vocab at 0x12c1d1a58>,
#  '乐乐': <gensim.models.keyedvectors.Vocab at 0x12c1d1a90>,
#  '情景': <gensim.models.keyedvectors.Vocab at 0x12c1d1ac8>,
#  '难以': <gensim.models.keyedvectors.Vocab at 0x12c1d1b00>,
#  '持续': <gensim.models.keyedvectors.Vocab at 0x12c1d1b38>,
#  '难': <gensim.models.keyedvectors.Vocab at 0x12c1d1b70>,
#  '改变': <gensim.models.keyedvectors.Vocab at 0x12c1d1ba8>,
#  '光大': <gensim.models.keyedvectors.Vocab at 0x12c1d1be0>,
#  '并未': <gensim.models.keyedvectors.Vocab at 0x12c1d1c18>,
#  '引起': <gensim.models.keyedvectors.Vocab at 0x12c1d1c50>,
#  '太大': <gensim.models.keyedvectors.Vocab at 0x12c1d1c88>,
#  '热情': <gensim.models.keyedvectors.Vocab at 0x12c1d1cc0>,
#  '成交量': <gensim.models.keyedvectors.Vocab at 0x12c1d1cf8>,
#  '较为': <gensim.models.keyedvectors.Vocab at 0x12c1d1d30>,
#  '平淡': <gensim.models.keyedvectors.Vocab at 0x12c1d1d68>,
#  '较大': <gensim.models.keyedvectors.Vocab at 0x12c1d1da0>,
#  '变化': <gensim.models.keyedvectors.Vocab at 0x12c1d1dd8>,
#  '成长': <gensim.models.keyedvectors.Vocab at 0x12c1d1e10>,
#  '股': <gensim.models.keyedvectors.Vocab at 0x12c1d1e48>,
#  '题材股': <gensim.models.keyedvectors.Vocab at 0x12c1d1e80>,
#  '全天': <gensim.models.keyedvectors.Vocab at 0x12c1d1eb8>,
#  '低迷': <gensim.models.keyedvectors.Vocab at 0x12c1d1ef0>,
#  '表明': <gensim.models.keyedvectors.Vocab at 0x12c1d1f28>,
#  '很少': <gensim.models.keyedvectors.Vocab at 0x12c1d1f60>,
#  '不同': <gensim.models.keyedvectors.Vocab at 0x12c1d1f98>,
#  '之间': <gensim.models.keyedvectors.Vocab at 0x12c1d1fd0>,
#  '腾挪': <gensim.models.keyedvectors.Vocab at 0x12c1d4048>,
#  '跷跷板': <gensim.models.keyedvectors.Vocab at 0x12c1d4080>,
#  '使得': <gensim.models.keyedvectors.Vocab at 0x12c1d40b8>,
#  '难有': <gensim.models.keyedvectors.Vocab at 0x12c1d40f0>,
#  '突破': <gensim.models.keyedvectors.Vocab at 0x12c1d4128>,
#  '中期': <gensim.models.keyedvectors.Vocab at 0x12c1d4160>,
#  '依旧': <gensim.models.keyedvectors.Vocab at 0x12c1d4198>,
#  '偏空': <gensim.models.keyedvectors.Vocab at 0x12c1d41d0>,
#  '维持': <gensim.models.keyedvectors.Vocab at 0x12c1d4208>,
#  '虽然': <gensim.models.keyedvectors.Vocab at 0x12c1d4240>,
#  '至今': <gensim.models.keyedvectors.Vocab at 0x12c1d4278>,
#  '夏普': <gensim.models.keyedvectors.Vocab at 0x12c1d42b0>,
#  '智能手机': <gensim.models.keyedvectors.Vocab at 0x12c1d42e8>,
#  '无法': <gensim.models.keyedvectors.Vocab at 0x12c1d4320>,
#  '排得': <gensim.models.keyedvectors.Vocab at 0x12c1d4358>,
#  '完全': <gensim.models.keyedvectors.Vocab at 0x12c1d4390>,
#  '没落': <gensim.models.keyedvectors.Vocab at 0x12c1d43c8>,
#  '2013': <gensim.models.keyedvectors.Vocab at 0x12c1d4400>,
#  '退出': <gensim.models.keyedvectors.Vocab at 0x12c1d4438>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x12c1d4470>,
#  '月份': <gensim.models.keyedvectors.Vocab at 0x12c1d44a8>,
#  '官方': <gensim.models.keyedvectors.Vocab at 0x12c1d44e0>,
#  '回归': <gensim.models.keyedvectors.Vocab at 0x12c1d4518>,
#  '预示': <gensim.models.keyedvectors.Vocab at 0x12c1d4550>,
#  '很快': <gensim.models.keyedvectors.Vocab at 0x12c1d4588>,
#  '新机': <gensim.models.keyedvectors.Vocab at 0x12c1d45c0>,
#  '登场': <gensim.models.keyedvectors.Vocab at 0x12c1d45f8>,
#  '第一款': <gensim.models.keyedvectors.Vocab at 0x12c1d4630>,
#  '登陆': <gensim.models.keyedvectors.Vocab at 0x12c1d4668>,
#  '又': <gensim.models.keyedvectors.Vocab at 0x12c1d46a0>,
#  '怎么样': <gensim.models.keyedvectors.Vocab at 0x12c1d46d8>,
#  '近日': <gensim.models.keyedvectors.Vocab at 0x12c1d4710>,
#  '型号': <gensim.models.keyedvectors.Vocab at 0x12c1d4748>,
#  'FS8016': <gensim.models.keyedvectors.Vocab at 0x12c1d4780>,
#  '神秘': <gensim.models.keyedvectors.Vocab at 0x12c1d47b8>,
#  '悄然': <gensim.models.keyedvectors.Vocab at 0x12c1d47f0>,
#  'GeekBench': <gensim.models.keyedvectors.Vocab at 0x12c1d4828>,
#  '分库': <gensim.models.keyedvectors.Vocab at 0x12c1d4860>,
#  '相关': <gensim.models.keyedvectors.Vocab at 0x12c1d4898>,
#  '机子': <gensim.models.keyedvectors.Vocab at 0x12c1d48d0>,
#  '并非': <gensim.models.keyedvectors.Vocab at 0x12c1d4908>,
#  '定位': <gensim.models.keyedvectors.Vocab at 0x12c1d4940>,
#  '所': <gensim.models.keyedvectors.Vocab at 0x12c1d4978>,
#  '660': <gensim.models.keyedvectors.Vocab at 0x12c1d49b0>,
#  '配备': <gensim.models.keyedvectors.Vocab at 0x12c1d49e8>,
#  '4GB': <gensim.models.keyedvectors.Vocab at 0x12c1d4a20>,
#  '内存': <gensim.models.keyedvectors.Vocab at 0x12c1d4a58>,
#  '最受': <gensim.models.keyedvectors.Vocab at 0x12c1d4a90>,
#  '瞩目': <gensim.models.keyedvectors.Vocab at 0x12c1d4ac8>,
#  '芯片': <gensim.models.keyedvectors.Vocab at 0x12c1d4b00>,
#  '之一': <gensim.models.keyedvectors.Vocab at 0x12c1d4b38>,
#  '采用': <gensim.models.keyedvectors.Vocab at 0x12c1d4b70>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x12c1d4ba8>,
#  '纳米': <gensim.models.keyedvectors.Vocab at 0x12c1d4be0>,
#  '工艺': <gensim.models.keyedvectors.Vocab at 0x12c1d4c18>,
#  '八个': <gensim.models.keyedvectors.Vocab at 0x12c1d4c50>,
#  'Kryo': <gensim.models.keyedvectors.Vocab at 0x12c1d4c88>,
#  '260': <gensim.models.keyedvectors.Vocab at 0x12c1d4cc0>,
#  '设计': <gensim.models.keyedvectors.Vocab at 0x12c1d4cf8>,
#  'Adreno': <gensim.models.keyedvectors.Vocab at 0x12c1d4d30>,
#  '512': <gensim.models.keyedvectors.Vocab at 0x12c1d4d68>,
#  'X12': <gensim.models.keyedvectors.Vocab at 0x12c1d4da0>,
#  'LTE': <gensim.models.keyedvectors.Vocab at 0x12c1d4dd8>,
#  '调制解调器': <gensim.models.keyedvectors.Vocab at 0x12c1d4e10>,
#  '当前': <gensim.models.keyedvectors.Vocab at 0x12c1d4e48>,
#  '市面上': <gensim.models.keyedvectors.Vocab at 0x12c1d4e80>,
#  '只有': <gensim.models.keyedvectors.Vocab at 0x12c1d4eb8>,
#  '上市': <gensim.models.keyedvectors.Vocab at 0x12c1d4ef0>,
#  '销售': <gensim.models.keyedvectors.Vocab at 0x12c1d4f28>,
#  'OPPO': <gensim.models.keyedvectors.Vocab at 0x12c1d4f60>,
#  'R11': <gensim.models.keyedvectors.Vocab at 0x12c1d4f98>,
#  '核新能': <gensim.models.keyedvectors.Vocab at 0x12c1d4fd0>,
#  '820': <gensim.models.keyedvectors.Vocab at 0x12c1d5048>,
#  '强': <gensim.models.keyedvectors.Vocab at 0x12c1d5080>,
#  '单核': <gensim.models.keyedvectors.Vocab at 0x12c1d50b8>,
#  '改进': <gensim.models.keyedvectors.Vocab at 0x12c1d50f0>,
#  '明显': <gensim.models.keyedvectors.Vocab at 0x12c1d5128>,
#  '所以': <gensim.models.keyedvectors.Vocab at 0x12c1d5160>,
#  '放在': <gensim.models.keyedvectors.Vocab at 0x12c1d5198>,
#  '变成': <gensim.models.keyedvectors.Vocab at 0x12c1d51d0>,
#  '高端': <gensim.models.keyedvectors.Vocab at 0x12c1d5208>,
#  '机': <gensim.models.keyedvectors.Vocab at 0x12c1d5240>,
#  '不过': <gensim.models.keyedvectors.Vocab at 0x12c1d5278>,
#  '签署': <gensim.models.keyedvectors.Vocab at 0x12c1d52b0>,
#  '排他性': <gensim.models.keyedvectors.Vocab at 0x12c1d52e8>,
#  '协议': <gensim.models.keyedvectors.Vocab at 0x12c1d5320>,
#  '独占': <gensim.models.keyedvectors.Vocab at 0x12c1d5358>,
#  ...}

# %% [markdown]
# ## 现在是 mini 测试集，如果大家把维基百科+新闻语料库的所有信息全部加上，那么效果肯定会不错的

# %% [markdown]
# ## Name Entity Recoginition

# %% [markdown]
# 区分出来什么是人名（person）， 组织机构名(organization), 地点(location)

# %% [markdown]
# ### 1. jieba

# %%
from jieba import posseg

# %% [markdown]
# posseg ==> Part of Speech Segment

# %%
text = """新华社华盛顿4月26日电 美国总统特朗普26日表示，美国将撤销在《武器贸易条约》上的签字。

特朗普当天在美国印第安纳州首府印第安纳波利斯举行的美国全国步枪协会年会上说，《武器贸易条约》是一个“严重误导的条约”，美国将撤销在该条约上的签字，联合国将很快收到美国正式拒绝该条约的通知。"""

# %%
# https://blog.csdn.net/suibianshen2012/article/details/53487157

# %%
for w in posseg.cut(text):
    print(w)
# Out:
# 新华社/nt
# 华盛顿/ns
# 4/m
# 月/m
# 26/m
# 日电/j
#  /x
# 美国/ns
# 总统/n
# 特朗普/nr
# 26/m
# 日/m
# 表示/v
# ，/x
# 美国/ns
# 将/d
# 撤销/v
# 在/p
# 《/x
# 武器/n
# 贸易/vn
# 条约/n
# 》/x
# 上/f
# 的/uj
# 签字/v
# 。/x
#
# /x
#
# /x
# 特朗普/nr
# 当天/t
# 在/p
# 美国/ns
# 印第安纳州/ns
# 首府/n
# 印第安纳波利斯/ns
# 举行/v
# 的/uj
# 美国/ns
# 全国/n
# 步枪/n
# 协会/n
# 年/m
# 会上/t
# 说/v
# ，/x
# 《/x
# 武器/n
# 贸易/vn
# 条约/n
# 》/x
# 是/v
# 一个/m
# “/x
# 严重/a
# 误导/n
# 的/uj
# 条约/n
# ”/x
# ，/x
# 美国/ns
# 将/d
# 撤销/v
# 在/p
# 该/r
# 条约/n
# 上/f
# 的/uj
# 签字/v
# ，/x
# 联合国/nt
# 将/d
# 很快/d
# 收到/v
# 美国/ns
# 正式/ad
# 拒绝/v
# 该/r
# 条约/n
# 的/uj
# 通知/v
# 。/x

# %% [markdown]
# ## 哈工大的 LTP

# %%
## https://pyltp.readthedocs.io/zh_CN/latest/api.html#id13

# %% [markdown]
# # Dependency Parsing 依存分析
