# %% [markdown]
# ## Mathmatical Foundation Part-II

# %%
points = [
    (0, 0), 
    (0.5, 0), 
    (0.5, 6.44),
    (6, 0),
    (6, 8),
    (5.5, 8),
    (5.5, 1.58),
    (0, 8)
]

# %%
import numpy as np

# %%
n_matrix = np.array([[0, 0.5, 0.5, 6, 6, 5.5, 5.5, 0], [0, 0, 6.44, 0, 8, 8, 1.58, 8]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def draw_segments(segments):
    for i, seg in enumerate(segments):
        _next = segments[(i+1)%len(segments)]
        x1, y1 = seg
        x2, y2 = _next
        plt.plot([x1, x2], [y1, y2])

# %%
draw_segments(points)

# %% [markdown]
# ## SDDS
#
# This is for test
#
# $\frac{1}{N}\sum_1^N$

# %%
transform_str = """
1 0.2
0.8 1
"""
transform_matrix = np.array([list(map(float, line.split())) for line in transform_str.split('\n') if line])

# %%
transfrom_by_matrix(n_matrix, transform_matrix)

# %%
def transfrom_by_matrix(original_matrix, A):
    transformed = np.dot(A, n_matrix)
    w, h = transformed.shape
    _points = []
    for i in range(h):
        _points.append(tuple(transformed[:, i]))
    draw_segments(_points)

# %%
transformed[:, 1]
# Out:
# array([0.5, 0. ])

# %%
assert len(points)  == 8

# %% [markdown]
# ## Probability

# %% [markdown]
# ### Definition

# %%
import random

# %%
occurences = [(i, j) for i in range(1, 7) for j in range(1, 7)]

# %%
exist_four = [t for t in occurences if 4 in t]

# %%
exist_three = [t for t in occurences if 3 in t]

# %%
(len(set(exist_four) & set(exist_three)))/ len(set(occurences))
# Out:
# 0.05555555555555555

# %%
len(set(exist_four)) / len(set(occurences))
# Out:
# 0.3055555555555556

# %%
len(set(occurences))
# Out:
# 36

# %% [markdown]
# ### Probability for dice

# %% [markdown]
# ## Normal Distribution

# %% [markdown]
# ## Center Limitation Theorm

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
from statistics import mean
from random import normalvariate, triangular, choice, vonmisesvariate, uniform

def normal(mu=0, sigma=1): return random.normalvariate(mu, sigma)

def repeated_hist(dist, n=10**6, bins=100):
    "Sample the distribution n times and make a histogram of the results."
    samples = [dist() for _ in range(n)]
    plt.hist(samples, bins=bins, normed=True)
    plt.title('{} (μ = {:.1f})'.format(dist.__name__, mean(samples)))
    plt.grid(axis='x')
    plt.yticks([], '')
    plt.show()

# %%
repeated_hist(normal, n=1000)

# %%
def sum10dice(): return sum(random.randint(1, 6) for _ in range(10))

# %%
def sum2dice(): return sum(random.randint(1, 6) for _ in range(2))

# %%
roll_dice()
# Out:
# 1

# %%
roll_dice()
# Out:
# 6

# %%
repeated_hist(sum2dice, n=10000)

# %%
repeated_hist(sum10dice, n=1000000)

# %% [markdown]
# ## Binary Sort
# ## Syntax Tree

# %% [markdown]
# ## Cut-rob for Dynamic Progrmmming
